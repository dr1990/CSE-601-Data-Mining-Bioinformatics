# %%
import numpy as np
import pandas as pd

# %%
# Reading data from file and appending it with gene identifiers

file_data = pd.read_csv('C:\\Users\\Linus-PC\\Desktop\\associationruletestdata.txt', sep='\t', header=None,
                        index_col=None)

record_count = file_data.shape[0]  # number of rows
attribute_count = file_data.shape[1]  # number of columns

# Changing the column index to start from 1 instead of 0
file_data.columns = np.arange(1, attribute_count + 1)

for i in range(1, file_data.shape[1]):
    file_data[i] = 'G' + str(i) + '_' + file_data[i]
    
file_data
# Out:
#         1        2        3        4        5        6        7        8    \
# 0     G1_Up    G2_Up  G3_Down    G4_Up  G5_Down    G6_Up    G7_Up  G8_Down
# 1     G1_Up  G2_Down    G3_Up  G4_Down    G5_Up  G6_Down  G7_Down  G8_Down
# 2   G1_Down  G2_Down    G3_Up    G4_Up    G5_Up    G6_Up  G7_Down    G8_Up
# 3   G1_Down  G2_Down  G3_Down  G4_Down  G5_Down  G6_Down  G7_Down    G8_Up
# 4     G1_Up    G2_Up  G3_Down  G4_Down  G5_Down  G6_Down    G7_Up    G8_Up
# 5     G1_Up  G2_Down  G3_Down  G4_Down    G5_Up    G6_Up    G7_Up  G8_Down
# 6     G1_Up    G2_Up  G3_Down    G4_Up    G5_Up  G6_Down    G7_Up    G8_Up
# 7   G1_Down  G2_Down    G3_Up    G4_Up    G5_Up    G6_Up    G7_Up  G8_Down
# 8     G1_Up  G2_Down    G3_Up  G4_Down  G5_Down    G6_Up  G7_Down  G8_Down
# 9   G1_Down  G2_Down    G3_Up  G4_Down    G5_Up    G6_Up  G7_Down  G8_Down
# 10    G1_Up  G2_Down    G3_Up    G4_Up  G5_Down  G6_Down    G7_Up    G8_Up
# 11  G1_Down    G2_Up  G3_Down  G4_Down  G5_Down  G6_Down    G7_Up    G8_Up
# 12    G1_Up  G2_Down  G3_Down  G4_Down    G5_Up    G6_Up    G7_Up    G8_Up
# 13    G1_Up  G2_Down    G3_Up  G4_Down  G5_Down  G6_Down  G7_Down    G8_Up
# 14    G1_Up    G2_Up  G3_Down    G4_Up    G5_Up    G6_Up  G7_Down    G8_Up
# 15    G1_Up  G2_Down    G3_Up    G4_Up    G5_Up    G6_Up  G7_Down  G8_Down
# 16  G1_Down  G2_Down    G3_Up  G4_Down    G5_Up  G6_Down    G7_Up    G8_Up
# 17    G1_Up  G2_Down  G3_Down  G4_Down    G5_Up    G6_Up    G7_Up  G8_Down
# 18    G1_Up  G2_Down  G3_Down  G4_Down    G5_Up    G6_Up    G7_Up    G8_Up
# 19    G1_Up  G2_Down    G3_Up    G4_Up  G5_Down  G6_Down    G7_Up    G8_Up
# 20    G1_Up  G2_Down  G3_Down  G4_Down    G5_Up    G6_Up  G7_Down  G8_Down
# 21    G1_Up    G2_Up  G3_Down    G4_Up    G5_Up    G6_Up    G7_Up  G8_Down
# 22    G1_Up  G2_Down  G3_Down    G4_Up  G5_Down  G6_Down    G7_Up    G8_Up
# 23    G1_Up    G2_Up    G3_Up  G4_Down  G5_Down    G6_Up  G7_Down    G8_Up
# 24    G1_Up  G2_Down    G3_Up    G4_Up    G5_Up    G6_Up    G7_Up  G8_Down
# 25  G1_Down    G2_Up  G3_Down    G4_Up  G5_Down  G6_Down  G7_Down  G8_Down
# 26  G1_Down  G2_Down    G3_Up  G4_Down  G5_Down  G6_Down  G7_Down    G8_Up
# 27  G1_Down    G2_Up  G3_Down    G4_Up  G5_Down  G6_Down  G7_Down    G8_Up
# 28    G1_Up    G2_Up  G3_Down    G4_Up    G5_Up    G6_Up  G7_Down  G8_Down
# 29  G1_Down    G2_Up  G3_Down  G4_Down  G5_Down    G6_Up    G7_Up    G8_Up
# ..      ...      ...      ...      ...      ...      ...      ...      ...
# 70    G1_Up  G2_Down  G3_Down  G4_Down  G5_Down    G6_Up  G7_Down  G8_Down
# 71    G1_Up    G2_Up    G3_Up  G4_Down    G5_Up    G6_Up  G7_Down    G8_Up
# 72    G1_Up  G2_Down  G3_Down    G4_Up  G5_Down    G6_Up  G7_Down    G8_Up
# 73    G1_Up  G2_Down  G3_Down    G4_Up  G5_Down  G6_Down    G7_Up    G8_Up
# 74  G1_Down  G2_Down  G3_Down    G4_Up    G5_Up    G6_Up    G7_Up  G8_Down
# 75    G1_Up  G2_Down  G3_Down    G4_Up    G5_Up    G6_Up    G7_Up    G8_Up
# 76    G1_Up    G2_Up    G3_Up    G4_Up    G5_Up    G6_Up  G7_Down  G8_Down
# 77    G1_Up    G2_Up  G3_Down  G4_Down  G5_Down    G6_Up    G7_Up    G8_Up
# 78  G1_Down  G2_Down    G3_Up  G4_Down    G5_Up    G6_Up    G7_Up  G8_Down
# 79  G1_Down  G2_Down    G3_Up    G4_Up    G5_Up  G6_Down    G7_Up    G8_Up
# 80    G1_Up  G2_Down  G3_Down    G4_Up  G5_Down  G6_Down  G7_Down    G8_Up
# 81    G1_Up    G2_Up  G3_Down    G4_Up    G5_Up  G6_Down  G7_Down    G8_Up
# 82    G1_Up  G2_Down    G3_Up  G4_Down    G5_Up    G6_Up  G7_Down    G8_Up
# 83    G1_Up  G2_Down  G3_Down    G4_Up    G5_Up    G6_Up    G7_Up    G8_Up
# 84    G1_Up    G2_Up    G3_Up    G4_Up    G5_Up    G6_Up    G7_Up    G8_Up
# 85  G1_Down  G2_Down  G3_Down    G4_Up    G5_Up    G6_Up    G7_Up    G8_Up
# 86    G1_Up  G2_Down  G3_Down    G4_Up  G5_Down  G6_Down  G7_Down    G8_Up
# 87  G1_Down    G2_Up  G3_Down  G4_Down  G5_Down    G6_Up  G7_Down    G8_Up
# 88    G1_Up  G2_Down    G3_Up    G4_Up    G5_Up    G6_Up  G7_Down  G8_Down
# 89    G1_Up    G2_Up    G3_Up  G4_Down  G5_Down    G6_Up    G7_Up    G8_Up
# 90    G1_Up  G2_Down    G3_Up  G4_Down  G5_Down    G6_Up    G7_Up    G8_Up
# 91  G1_Down    G2_Up    G3_Up    G4_Up    G5_Up  G6_Down    G7_Up    G8_Up
# 92    G1_Up    G2_Up  G3_Down  G4_Down  G5_Down    G6_Up  G7_Down    G8_Up
# 93    G1_Up  G2_Down    G3_Up  G4_Down  G5_Down    G6_Up  G7_Down    G8_Up
# 94    G1_Up  G2_Down    G3_Up    G4_Up  G5_Down    G6_Up    G7_Up    G8_Up
# 95  G1_Down    G2_Up  G3_Down    G4_Up  G5_Down    G6_Up    G7_Up    G8_Up
# 96    G1_Up  G2_Down  G3_Down    G4_Up    G5_Up    G6_Up  G7_Down    G8_Up
# 97    G1_Up  G2_Down    G3_Up  G4_Down    G5_Up    G6_Up  G7_Down    G8_Up
# 98  G1_Down    G2_Up    G3_Up  G4_Down    G5_Up  G6_Down    G7_Up    G8_Up
# 99  G1_Down    G2_Up  G3_Down    G4_Up  G5_Down  G6_Down    G7_Up    G8_Up
#
#         9         10       ...             92        93        94        95   \
# 0   G9_Down    G10_Up      ...          G92_Up    G93_Up  G94_Down    G95_Up
# 1   G9_Down    G10_Up      ...          G92_Up    G93_Up  G94_Down  G95_Down
# 2     G9_Up    G10_Up      ...          G92_Up    G93_Up  G94_Down    G95_Up
# 3   G9_Down    G10_Up      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 4     G9_Up  G10_Down      ...          G92_Up    G93_Up  G94_Down  G95_Down
# 5     G9_Up  G10_Down      ...        G92_Down    G93_Up    G94_Up    G95_Up
# 6   G9_Down  G10_Down      ...        G92_Down    G93_Up    G94_Up    G95_Up
# 7   G9_Down  G10_Down      ...        G92_Down  G93_Down  G94_Down    G95_Up
# 8     G9_Up  G10_Down      ...          G92_Up    G93_Up    G94_Up  G95_Down
# 9   G9_Down  G10_Down      ...        G92_Down    G93_Up    G94_Up  G95_Down
# 10    G9_Up  G10_Down      ...        G92_Down  G93_Down    G94_Up  G95_Down
# 11  G9_Down  G10_Down      ...        G92_Down    G93_Up  G94_Down  G95_Down
# 12  G9_Down  G10_Down      ...        G92_Down  G93_Down  G94_Down  G95_Down
# 13  G9_Down  G10_Down      ...        G92_Down  G93_Down    G94_Up  G95_Down
# 14  G9_Down  G10_Down      ...        G92_Down    G93_Up    G94_Up  G95_Down
# 15    G9_Up  G10_Down      ...        G92_Down    G93_Up    G94_Up    G95_Up
# 16  G9_Down    G10_Up      ...          G92_Up  G93_Down  G94_Down    G95_Up
# 17    G9_Up  G10_Down      ...          G92_Up    G93_Up    G94_Up    G95_Up
# 18  G9_Down  G10_Down      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 19  G9_Down    G10_Up      ...        G92_Down  G93_Down  G94_Down  G95_Down
# 20    G9_Up  G10_Down      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 21    G9_Up  G10_Down      ...          G92_Up    G93_Up  G94_Down  G95_Down
# 22    G9_Up  G10_Down      ...        G92_Down  G93_Down  G94_Down    G95_Up
# 23  G9_Down    G10_Up      ...        G92_Down  G93_Down    G94_Up  G95_Down
# 24  G9_Down    G10_Up      ...          G92_Up  G93_Down  G94_Down    G95_Up
# 25    G9_Up  G10_Down      ...          G92_Up    G93_Up  G94_Down    G95_Up
# 26  G9_Down  G10_Down      ...        G92_Down    G93_Up  G94_Down    G95_Up
# 27    G9_Up  G10_Down      ...          G92_Up    G93_Up  G94_Down  G95_Down
# 28  G9_Down  G10_Down      ...        G92_Down    G93_Up    G94_Up  G95_Down
# 29    G9_Up    G10_Up      ...          G92_Up    G93_Up    G94_Up    G95_Up
# ..      ...       ...      ...             ...       ...       ...       ...
# 70  G9_Down  G10_Down      ...          G92_Up    G93_Up    G94_Up  G95_Down
# 71  G9_Down    G10_Up      ...        G92_Down    G93_Up    G94_Up    G95_Up
# 72    G9_Up  G10_Down      ...          G92_Up    G93_Up  G94_Down  G95_Down
# 73  G9_Down  G10_Down      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 74  G9_Down  G10_Down      ...        G92_Down    G93_Up    G94_Up    G95_Up
# 75  G9_Down  G10_Down      ...        G92_Down  G93_Down    G94_Up    G95_Up
# 76  G9_Down    G10_Up      ...        G92_Down    G93_Up  G94_Down  G95_Down
# 77  G9_Down    G10_Up      ...        G92_Down    G93_Up  G94_Down  G95_Down
# 78    G9_Up    G10_Up      ...          G92_Up  G93_Down  G94_Down  G95_Down
# 79    G9_Up  G10_Down      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 80    G9_Up    G10_Up      ...        G92_Down    G93_Up  G94_Down    G95_Up
# 81    G9_Up  G10_Down      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 82    G9_Up  G10_Down      ...          G92_Up    G93_Up    G94_Up  G95_Down
# 83    G9_Up  G10_Down      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 84  G9_Down    G10_Up      ...        G92_Down  G93_Down    G94_Up  G95_Down
# 85  G9_Down  G10_Down      ...        G92_Down    G93_Up  G94_Down    G95_Up
# 86    G9_Up  G10_Down      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 87    G9_Up  G10_Down      ...        G92_Down  G93_Down  G94_Down  G95_Down
# 88  G9_Down  G10_Down      ...          G92_Up  G93_Down    G94_Up  G95_Down
# 89  G9_Down    G10_Up      ...          G92_Up  G93_Down  G94_Down  G95_Down
# 90  G9_Down  G10_Down      ...          G92_Up    G93_Up    G94_Up  G95_Down
# 91    G9_Up  G10_Down      ...        G92_Down    G93_Up    G94_Up    G95_Up
# 92    G9_Up  G10_Down      ...          G92_Up    G93_Up  G94_Down  G95_Down
# 93  G9_Down  G10_Down      ...        G92_Down  G93_Down    G94_Up    G95_Up
# 94    G9_Up  G10_Down      ...          G92_Up  G93_Down    G94_Up    G95_Up
# 95  G9_Down    G10_Up      ...        G92_Down  G93_Down    G94_Up  G95_Down
# 96    G9_Up    G10_Up      ...          G92_Up    G93_Up  G94_Down    G95_Up
# 97    G9_Up  G10_Down      ...        G92_Down  G93_Down    G94_Up  G95_Down
# 98    G9_Up  G10_Down      ...        G92_Down  G93_Down    G94_Up  G95_Down
# 99    G9_Up    G10_Up      ...          G92_Up    G93_Up    G94_Up  G95_Down
#
#          96        97        98        99         100            101
# 0   G96_Down  G97_Down  G98_Down    G99_Up  G100_Down            ALL
# 1   G96_Down  G97_Down  G98_Down    G99_Up    G100_Up            ALL
# 2   G96_Down  G97_Down    G98_Up    G99_Up    G100_Up            ALL
# 3   G96_Down    G97_Up  G98_Down    G99_Up  G100_Down            AML
# 4   G96_Down  G97_Down  G98_Down    G99_Up    G100_Up  Breast Cancer
# 5   G96_Down  G97_Down  G98_Down    G99_Up  G100_Down            ALL
# 6   G96_Down    G97_Up    G98_Up  G99_Down  G100_Down            AML
# 7   G96_Down  G97_Down    G98_Up  G99_Down  G100_Down            ALL
# 8   G96_Down    G97_Up  G98_Down  G99_Down  G100_Down  Breast Cancer
# 9   G96_Down    G97_Up    G98_Up  G99_Down    G100_Up            ALL
# 10  G96_Down  G97_Down    G98_Up  G99_Down  G100_Down  Breast Cancer
# 11  G96_Down  G97_Down    G98_Up    G99_Up  G100_Down            ALL
# 12  G96_Down  G97_Down    G98_Up    G99_Up    G100_Up  Breast Cancer
# 13  G96_Down  G97_Down  G98_Down    G99_Up  G100_Down            ALL
# 14    G96_Up    G97_Up    G98_Up  G99_Down    G100_Up            ALL
# 15    G96_Up  G97_Down    G98_Up  G99_Down  G100_Down  Breast Cancer
# 16  G96_Down  G97_Down    G98_Up  G99_Down    G100_Up            ALL
# 17    G96_Up  G97_Down  G98_Down    G99_Up  G100_Down  Breast Cancer
# 18  G96_Down    G97_Up  G98_Down    G99_Up  G100_Down  Breast Cancer
# 19    G96_Up    G97_Up    G98_Up    G99_Up    G100_Up  Breast Cancer
# 20    G96_Up    G97_Up    G98_Up    G99_Up  G100_Down   Colon Cancer
# 21  G96_Down  G97_Down    G98_Up  G99_Down  G100_Down            ALL
# 22  G96_Down    G97_Up  G98_Down  G99_Down  G100_Down  Breast Cancer
# 23    G96_Up    G97_Up    G98_Up  G99_Down  G100_Down            AML
# 24  G96_Down    G97_Up    G98_Up    G99_Up    G100_Up   Colon Cancer
# 25  G96_Down  G97_Down    G98_Up  G99_Down  G100_Down            ALL
# 26  G96_Down  G97_Down    G98_Up    G99_Up    G100_Up            ALL
# 27    G96_Up    G97_Up  G98_Down  G99_Down  G100_Down            AML
# 28    G96_Up    G97_Up  G98_Down  G99_Down  G100_Down            ALL
# 29  G96_Down  G97_Down    G98_Up  G99_Down  G100_Down            ALL
# ..       ...       ...       ...       ...        ...            ...
# 70  G96_Down    G97_Up  G98_Down    G99_Up    G100_Up            AML
# 71    G96_Up    G97_Up  G98_Down  G99_Down  G100_Down  Breast Cancer
# 72  G96_Down    G97_Up    G98_Up    G99_Up    G100_Up  Breast Cancer
# 73    G96_Up  G97_Down    G98_Up  G99_Down    G100_Up  Breast Cancer
# 74  G96_Down    G97_Up    G98_Up    G99_Up  G100_Down   Colon Cancer
# 75    G96_Up    G97_Up  G98_Down    G99_Up  G100_Down  Breast Cancer
# 76  G96_Down  G97_Down    G98_Up  G99_Down  G100_Down            ALL
# 77  G96_Down  G97_Down    G98_Up    G99_Up  G100_Down            ALL
# 78  G96_Down  G97_Down  G98_Down  G99_Down    G100_Up            ALL
# 79  G96_Down    G97_Up  G98_Down    G99_Up    G100_Up  Breast Cancer
# 80  G96_Down  G97_Down  G98_Down  G99_Down    G100_Up            ALL
# 81    G96_Up    G97_Up    G98_Up    G99_Up  G100_Down  Breast Cancer
# 82    G96_Up  G97_Down  G98_Down    G99_Up    G100_Up            ALL
# 83  G96_Down  G97_Down  G98_Down    G99_Up    G100_Up  Breast Cancer
# 84  G96_Down  G97_Down  G98_Down  G99_Down  G100_Down  Breast Cancer
# 85    G96_Up  G97_Down    G98_Up    G99_Up    G100_Up  Breast Cancer
# 86  G96_Down  G97_Down  G98_Down  G99_Down    G100_Up  Breast Cancer
# 87  G96_Down  G97_Down  G98_Down  G99_Down  G100_Down            ALL
# 88    G96_Up  G97_Down    G98_Up    G99_Up    G100_Up  Breast Cancer
# 89  G96_Down  G97_Down    G98_Up  G99_Down    G100_Up            ALL
# 90    G96_Up  G97_Down    G98_Up    G99_Up  G100_Down            AML
# 91  G96_Down  G97_Down  G98_Down    G99_Up  G100_Down            ALL
# 92  G96_Down  G97_Down    G98_Up    G99_Up  G100_Down            ALL
# 93    G96_Up    G97_Up  G98_Down  G99_Down  G100_Down            AML
# 94    G96_Up  G97_Down    G98_Up    G99_Up  G100_Down            ALL
# 95  G96_Down  G97_Down    G98_Up    G99_Up  G100_Down            ALL
# 96  G96_Down    G97_Up  G98_Down  G99_Down    G100_Up  Breast Cancer
# 97  G96_Down    G97_Up  G98_Down    G99_Up    G100_Up   Colon Cancer
# 98  G96_Down    G97_Up    G98_Up  G99_Down  G100_Down  Breast Cancer
# 99  G96_Down  G97_Down    G98_Up    G99_Up    G100_Up  Breast Cancer
#
# [100 rows x 101 columns]

# %%
# Converting the input data into an array of sample sets
# Converted data to sets for intersection operation while matching itemsets

# Converting input data table into array of arrays, eliminating the last column (disease)
file_data_arr = file_data.values[:, :attribute_count]

sample_sets = []
for i in file_data_arr:
    sample_sets.append(set(i))

# Includes all column data.
raw_set = []
for i in file_data_arr:
    for j in i:
        if {j} not in raw_set:
            raw_set.append({j})
            
# sample_sets

# %%
def generate_rules(min_confidence, freq_item_sets, freq_item_support_map):
    for freq_k_item_set in freq_item_sets:
        H1= [set([x]) for x in freq_k_item_set]    # breaking the frequent itemset into a list of length 1 item sets
        ap_rules(freq_k_item_set, H1, 1, freq_item_support_map, min_confidence)

# %%
# Method that generates association rules from the given frequent itemsets
# Reference - https://www-users.cs.umn.edu/~kumar001/dmbook/ch6.pdf Pg 351
def ap_rules(freq_k_item_set, Hm, Hsize, freq_item_support_map, min_confidence):
    k = len(freq_k_item_set)
    m = Hsize
    if(k > m+1):
        Hmplus1 = generate_merge_sets(Hm,m+1)
        for hplus1 in Hmplus1:
            confidence = freq_item_support_map[getKey(freq_k_item_set)][1]/freq_item_support_map[getKey(freq_k_item_set - hplus1)][1]
            if confidence >= min_confidence:
                print(hplus1 , " implies ", (freq_k_item_set - hplus1))
            else:
                Hmplus1.remove(hplus1)
        ap_rules(freq_k_item_set, Hmplus1, Hsize+1, freq_item_support_map, min_confidence)

# %%
def has_unique_last_items(a, b, length):
    first = sorted(a)
    second = sorted(b)

    i = 1
    for x, y in zip(first, second):
        if i == length - 1 and x != y:
            return True
        if i == length - 1 and x == y:
            return False
        if x != y:
            return False
        i += 1
    return True

    
getKey = lambda x: str(sorted(x))

# https://www-users.cs.umn.edu/~kumar001/dmbook/ch6.pdf
# Using F(k-1) * F(k-1) method
def generate_merge_sets(freq_sets, set_length):
    new_item_sets = []

    for i in range(len(freq_sets)):
        for j in range(i, len(freq_sets)):
            if set_length < 2 or has_unique_last_items(freq_sets[i], freq_sets[j], set_length):
#             if set_length < 2 or len(freq_sets[i] - freq_sets[j]) == 1:    # Set difference returns the uncommon element from LHS
                union_set = freq_sets[i].union(freq_sets[j])
                if len(union_set) == set_length:
                    sorted_set = set(sorted(union_set))
                    new_item_sets.append(sorted_set)
    return new_item_sets

# %%
min_support_values = [30, 40, 50, 60, 70]

for min_support in min_support_values[:1]:
    print('\nSupport is set to be ' + str(min_support) + '%')

    flag = True  # Flag used to determine when to stop
    length = 1  # length of frequent item sets

    item_sets = raw_set
    sum = 0
    freq_item_support_map = dict()
    while flag:
        freq_item_sets = []
        item_set_support = []  # Temporary list to store support values of current item sets
        for item_set in item_sets:
            count = 0
            for sample in sample_sets:
                if item_set - sample == set():    # subset operation
                    count += 1
            # compute and store support value
            sup = round((count * 100 / record_count))
            # item_set_support.append(sup)
            if sup >= min_support:
                freq_item_sets.append(item_set)
                freq_item_support_map[getKey(item_set)] = (item_set, sup)     # stores [string represent of frequent itemset -> tuple of (set representation of item_set, support)]

        # for index, sup in enumerate(item_set_support):
        #     if sup >= min_support:
        #         freq_item_sets.append(item_sets[index])
        #         freq_item_support_map[list()] = sup

        generate_rules(0.7, freq_item_sets, freq_item_support_map)

        sum += len(freq_item_sets)
        if len(freq_item_sets) != 0:
            print('number of length-' + str(length) + ' frequent itemsets: ' + str(len(freq_item_sets)))
        else:
            print('number of all lengths frequent itemsets:' + str(sum))
            sum = 0

        if len(freq_item_sets) == 0:
            flag = False;
        else:
            length += 1
            item_sets = generate_merge_sets(freq_item_sets, length)
# Out:
# Support is set to be 30%
# number of length-1 frequent itemsets: 196
# number of length-2 frequent itemsets: 5340
# {'G1_Up', 'G10_Down'}  implies  {'G44_Up'}
# {'G13_Down', 'G82_Down'}  implies  {'G44_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G81_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'ALL'}
# {'G13_Down', 'G82_Down'}  implies  {'ALL'}
# {'G72_Up', 'G59_Up'}  implies  {'G18_Up'}
# {'G96_Down', 'G59_Up'}  implies  {'G20_Up'}
# {'G8_Up', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G10_Down', 'G28_Down'}  implies  {'G44_Up'}
# {'G72_Up', 'G82_Down'}  implies  {'G30_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G33_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G37_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G37_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G40_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G44_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G44_Down'}
# {'G44_Down', 'G96_Down'}  implies  {'ALL'}
# {'G72_Up', 'G59_Up'}  implies  {'G81_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G82_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G97_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G77_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G85_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G68_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G81_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G82_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G3_Up'}
# {'G88_Down', 'G59_Up'}  implies  {'G4_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G71_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G81_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G82_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G97_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G97_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G99_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'ALL'}
# {'G97_Down', 'G96_Down'}  implies  {'ALL'}
# {'G38_Down', 'G32_Down'}  implies  {'G97_Up'}
# {'G38_Down', 'G10_Down'}  implies  {'G44_Up'}
# {'G54_Up', 'G80_Down'}  implies  {'Breast Cancer'}
# {'G10_Down', 'G65_Down'}  implies  {'G44_Up'}
# {'G80_Down', 'G81_Up'}  implies  {'Breast Cancer'}
# {'G88_Down', 'G10_Down'}  implies  {'G44_Up'}
# {'G88_Down', 'G80_Down'}  implies  {'Breast Cancer'}
# {'G10_Down', 'G32_Down'}  implies  {'G44_Up'}
# {'G41_Down', 'G10_Down'}  implies  {'G44_Up'}
# {'G10_Down', 'G67_Up'}  implies  {'G44_Up'}
# number of length-3 frequent itemsets: 5287
# {'G6_Up', 'G32_Down'}  implies  {'G21_Up', 'G1_Up'}
# {'G1_Up', 'G32_Down'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G65_Down'}  implies  {'G58_Down', 'G1_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G1_Up', 'G91_Up'}
# {'G6_Up', 'G1_Up'}  implies  {'G58_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G58_Down', 'G1_Up'}
# {'G1_Up', 'G59_Up'}  implies  {'G6_Up', 'G67_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G58_Down', 'G1_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G6_Up', 'G47_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G6_Up', 'G1_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G70_Down', 'G1_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G6_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G1_Up', 'G91_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G1_Up', 'G94_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G6_Up', 'G94_Up'}
# {'G1_Up', 'G91_Up'}  implies  {'G6_Up', 'G65_Down'}
# {'G6_Up', 'G32_Down'}  implies  {'G58_Down', 'G1_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G1_Up', 'G32_Down'}
# {'G70_Down', 'G6_Up'}  implies  {'G1_Up', 'G32_Down'}
# {'G70_Down', 'G1_Up'}  implies  {'G6_Up', 'G32_Down'}
# {'G70_Down', 'G32_Down'}  implies  {'G6_Up', 'G1_Up'}
# {'G6_Up', 'G1_Up'}  implies  {'G70_Down', 'G32_Down'}
# {'G6_Up', 'G32_Down'}  implies  {'G70_Down', 'G1_Up'}
# {'G1_Up', 'G32_Down'}  implies  {'G70_Down', 'G6_Up'}
# {'G6_Up', 'G1_Up'}  implies  {'G32_Down', 'G91_Up'}
# {'G6_Up', 'G32_Down'}  implies  {'G1_Up', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G1_Up', 'G32_Down'}
# {'G6_Up', 'G1_Up'}  implies  {'G32_Down', 'G67_Up'}
# {'G6_Up', 'G32_Down'}  implies  {'G1_Up', 'G67_Up'}
# {'G6_Up', 'G67_Up'}  implies  {'G1_Up', 'G32_Down'}
# {'G1_Up', 'G32_Down'}  implies  {'G6_Up', 'G67_Up'}
# {'G1_Up', 'G67_Up'}  implies  {'G6_Up', 'G32_Down'}
# {'G32_Down', 'G67_Up'}  implies  {'G6_Up', 'G1_Up'}
# {'G70_Down', 'G6_Up'}  implies  {'G1_Up', 'G91_Up'}
# {'G6_Up', 'G1_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G6_Up', 'G67_Up'}  implies  {'G1_Up', 'G91_Up'}
# {'G1_Up', 'G91_Up'}  implies  {'G6_Up', 'G67_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G21_Up', 'G1_Up'}
# {'G38_Down', 'G32_Down'}  implies  {'G21_Up', 'G1_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G21_Up', 'G1_Up'}
# {'G38_Down', 'G91_Up'}  implies  {'G21_Up', 'G1_Up'}
# {'G38_Down', 'G94_Up'}  implies  {'G21_Up', 'G1_Up'}
# {'G1_Up', 'G94_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G47_Up', 'G94_Up'}  implies  {'G21_Up', 'G1_Up'}
# {'G21_Up', 'G1_Up'}  implies  {'G47_Up', 'G94_Up'}
# {'G54_Up', 'G24_Down'}  implies  {'G8_Up', 'G1_Up'}
# {'G1_Up', 'G28_Down'}  implies  {'G67_Up', 'G52_Down'}
# {'G47_Up', 'G38_Down'}  implies  {'G1_Up', 'G28_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G65_Down', 'G28_Down'}
# {'G70_Down', 'G38_Down'}  implies  {'G1_Up', 'G28_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G28_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G70_Down', 'G1_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G94_Up', 'G28_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G28_Down', 'G67_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G65_Down', 'G52_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G52_Down', 'G67_Up'}
# {'G1_Up', 'G52_Down'}  implies  {'G47_Up', 'G67_Up'}
# {'G58_Down', 'G65_Down'}  implies  {'G30_Down', 'G1_Up'}
# {'G1_Up', 'G65_Down'}  implies  {'G58_Down', 'G30_Down'}
# {'G47_Up', 'G38_Down'}  implies  {'G58_Down', 'G1_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G58_Down', 'G47_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G58_Down', 'G65_Down'}
# {'G70_Down', 'G38_Down'}  implies  {'G58_Down', 'G1_Up'}
# {'G70_Down', 'G1_Up'}  implies  {'G58_Down', 'G38_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G58_Down', 'G91_Up'}
# {'G58_Down', 'G38_Down'}  implies  {'G1_Up', 'G91_Up'}
# {'G38_Down', 'G91_Up'}  implies  {'G58_Down', 'G1_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G58_Down', 'G67_Up'}
# {'G70_Down', 'G65_Down'}  implies  {'G58_Down', 'G1_Up'}
# {'G58_Down', 'G1_Up'}  implies  {'G70_Down', 'G65_Down'}
# {'G38_Down', 'G32_Down'}  implies  {'G58_Down', 'G1_Up'}
# {'G58_Down', 'G1_Up'}  implies  {'G32_Down', 'G65_Down'}
# {'G1_Up', 'G32_Down'}  implies  {'G58_Down', 'G65_Down'}
# {'G70_Down', 'G58_Down'}  implies  {'G1_Up', 'G32_Down'}
# {'G58_Down', 'G1_Up'}  implies  {'G70_Down', 'G32_Down'}
# {'G70_Down', 'G67_Up'}  implies  {'G58_Down', 'G1_Up'}
# {'G58_Down', 'G1_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G1_Up', 'G82_Down'}
# {'G38_Down', 'G65_Down'}  implies  {'G30_Down', 'G1_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G60_Up', 'G1_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G1_Up', 'G65_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G47_Up', 'G65_Down'}
# {'G38_Down', 'G65_Down'}  implies  {'G47_Up', 'G1_Up'}
# {'G47_Up', 'G1_Up'}  implies  {'G38_Down', 'G65_Down'}
# {'G47_Up', 'G38_Down'}  implies  {'G1_Up', 'G78_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G47_Up', 'G78_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G87_Up', 'G1_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G47_Up', 'G1_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G70_Down', 'G1_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G47_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G1_Up', 'G91_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G47_Up', 'G91_Up'}
# {'G38_Down', 'G91_Up'}  implies  {'G47_Up', 'G1_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G1_Up', 'G94_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G47_Up', 'G94_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G1_Up', 'G67_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G47_Up', 'G67_Up'}
# {'G38_Down', 'G67_Up'}  implies  {'G47_Up', 'G1_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G1_Up', 'G65_Down'}
# {'G70_Down', 'G1_Up'}  implies  {'G38_Down', 'G65_Down'}
# {'G38_Down', 'G65_Down'}  implies  {'G70_Down', 'G1_Up'}
# {'G38_Down', 'G65_Down'}  implies  {'G1_Up', 'G94_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G65_Down', 'G67_Up'}
# {'G38_Down', 'G65_Down'}  implies  {'G1_Up', 'G67_Up'}
# {'G38_Down', 'G67_Up'}  implies  {'G1_Up', 'G65_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G89_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G32_Down', 'G65_Down'}
# {'G70_Down', 'G38_Down'}  implies  {'G1_Up', 'G32_Down'}
# {'G70_Down', 'G1_Up'}  implies  {'G38_Down', 'G32_Down'}
# {'G70_Down', 'G32_Down'}  implies  {'G1_Up', 'G38_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G32_Down'}
# {'G38_Down', 'G32_Down'}  implies  {'G70_Down', 'G1_Up'}
# {'G1_Up', 'G32_Down'}  implies  {'G70_Down', 'G38_Down'}
# {'G38_Down', 'G32_Down'}  implies  {'G1_Up', 'G94_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G32_Down', 'G67_Up'}
# {'G38_Down', 'G32_Down'}  implies  {'G1_Up', 'G67_Up'}
# {'G38_Down', 'G67_Up'}  implies  {'G1_Up', 'G32_Down'}
# {'G1_Up', 'G32_Down'}  implies  {'G38_Down', 'G67_Up'}
# {'G1_Up', 'G67_Up'}  implies  {'G38_Down', 'G32_Down'}
# {'G32_Down', 'G67_Up'}  implies  {'G1_Up', 'G38_Down'}
# {'G70_Down', 'G38_Down'}  implies  {'G1_Up', 'G91_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G91_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G1_Up', 'G94_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G94_Up'}
# {'G38_Down', 'G94_Up'}  implies  {'G70_Down', 'G1_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G41_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G80_Down'}
# {'G70_Down', 'G38_Down'}  implies  {'G1_Up', 'G67_Up'}
# {'G70_Down', 'G1_Up'}  implies  {'G38_Down', 'G67_Up'}
# {'G70_Down', 'G67_Up'}  implies  {'G1_Up', 'G38_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G70_Down', 'G67_Up'}
# {'G38_Down', 'G67_Up'}  implies  {'G70_Down', 'G1_Up'}
# {'G1_Up', 'G67_Up'}  implies  {'G70_Down', 'G38_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G38_Down', 'G94_Up'}  implies  {'G1_Up', 'G91_Up'}
# {'G38_Down', 'G91_Up'}  implies  {'G1_Up', 'G94_Up'}
# {'G38_Down', 'G67_Up'}  implies  {'G1_Up', 'G91_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G94_Up', 'G67_Up'}
# {'G1_Up', 'G67_Up'}  implies  {'G47_Up', 'G65_Down'}
# {'G47_Up', 'G1_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G70_Down', 'G1_Up'}  implies  {'G32_Down', 'G65_Down'}
# {'G70_Down', 'G32_Down'}  implies  {'G1_Up', 'G65_Down'}
# {'G70_Down', 'G65_Down'}  implies  {'G1_Up', 'G32_Down'}
# {'G1_Up', 'G32_Down'}  implies  {'G70_Down', 'G65_Down'}
# {'G1_Up', 'G65_Down'}  implies  {'G70_Down', 'G32_Down'}
# {'G32_Down', 'G65_Down'}  implies  {'G70_Down', 'G1_Up'}
# {'G1_Up', 'G67_Up'}  implies  {'G32_Down', 'G65_Down'}
# {'G32_Down', 'G67_Up'}  implies  {'G1_Up', 'G65_Down'}
# {'G65_Down', 'G67_Up'}  implies  {'G1_Up', 'G32_Down'}
# {'G1_Up', 'G32_Down'}  implies  {'G65_Down', 'G67_Up'}
# {'G1_Up', 'G65_Down'}  implies  {'G32_Down', 'G67_Up'}
# {'G70_Down', 'G1_Up'}  implies  {'G65_Down', 'G67_Up'}
# {'G70_Down', 'G65_Down'}  implies  {'G1_Up', 'G67_Up'}
# {'G70_Down', 'G67_Up'}  implies  {'G1_Up', 'G65_Down'}
# {'G1_Up', 'G65_Down'}  implies  {'G70_Down', 'G67_Up'}
# {'G1_Up', 'G67_Up'}  implies  {'G70_Down', 'G65_Down'}
# {'G65_Down', 'G67_Up'}  implies  {'G70_Down', 'G1_Up'}
# {'G1_Up', 'G91_Up'}  implies  {'G94_Up', 'G65_Down'}
# {'G1_Up', 'G67_Up'}  implies  {'G94_Up', 'G65_Down'}
# {'G70_Down', 'G1_Up'}  implies  {'G32_Down', 'G67_Up'}
# {'G70_Down', 'G32_Down'}  implies  {'G1_Up', 'G67_Up'}
# {'G70_Down', 'G67_Up'}  implies  {'G1_Up', 'G32_Down'}
# {'G1_Up', 'G32_Down'}  implies  {'G70_Down', 'G67_Up'}
# {'G1_Up', 'G67_Up'}  implies  {'G70_Down', 'G32_Down'}
# {'G32_Down', 'G67_Up'}  implies  {'G70_Down', 'G1_Up'}
# {'G70_Down', 'G1_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G70_Down', 'G1_Up'}  implies  {'G94_Up', 'G67_Up'}
# {'G1_Up', 'G94_Up'}  implies  {'G70_Down', 'G67_Up'}
# {'G1_Up', 'G67_Up'}  implies  {'G70_Down', 'G94_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G6_Up', 'G10_Down'}
# {'G1_Up', 'G10_Down'}  implies  {'G21_Up', 'G38_Down'}
# {'G1_Up', 'G10_Down'}  implies  {'G47_Up', 'G21_Up'}
# {'G10_Down', 'G65_Down'}  implies  {'G58_Down', 'G1_Up'}
# {'G1_Up', 'G10_Down'}  implies  {'G2_Down', 'G94_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G47_Up', 'G10_Down'}
# {'G47_Up', 'G38_Down'}  implies  {'G1_Up', 'G10_Down'}
# {'G38_Down', 'G10_Down'}  implies  {'G47_Up', 'G1_Up'}
# {'G38_Down', 'G1_Up'}  implies  {'G10_Down', 'G65_Down'}
# {'G38_Down', 'G10_Down'}  implies  {'G1_Up', 'G65_Down'}
# {'G38_Down', 'G1_Up'}  implies  {'G10_Down', 'G94_Up'}
# {'G1_Up', 'G10_Down'}  implies  {'G38_Down', 'G94_Up'}
# {'G38_Down', 'G94_Up'}  implies  {'G1_Up', 'G10_Down'}
# {'G47_Up', 'G1_Up'}  implies  {'G10_Down', 'G65_Down'}
# {'G1_Up', 'G10_Down'}  implies  {'G47_Up', 'G65_Down'}
# {'G70_Down', 'G1_Up'}  implies  {'G10_Down', 'G65_Down'}
# {'G1_Up', 'G10_Down'}  implies  {'G70_Down', 'G65_Down'}
# {'G1_Up', 'G10_Down'}  implies  {'G65_Down', 'G67_Up'}
# {'G1_Up', 'G10_Down'}  implies  {'G94_Up', 'G91_Up'}
# {'G1_Up', 'G10_Down'}  implies  {'G94_Up', 'G67_Up'}
# {'G72_Up', 'G82_Down'}  implies  {'G5_Down', 'G59_Up'}
# {'G70_Down', 'G58_Down'}  implies  {'G6_Up', 'G21_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G70_Down', 'G21_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G21_Up', 'G91_Up'}
# {'G6_Up', 'G21_Up'}  implies  {'G58_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G58_Down', 'G21_Up'}
# {'G21_Up', 'G91_Up'}  implies  {'G58_Down', 'G6_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G6_Up', 'G21_Up'}
# {'G70_Down', 'G6_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G58_Down', 'G6_Up'}  implies  {'G47_Up', 'G21_Up'}
# {'G58_Down', 'G47_Up'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G21_Up'}  implies  {'G58_Down', 'G47_Up'}
# {'G47_Up', 'G91_Up'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G47_Up'}  implies  {'G21_Up', 'G94_Up'}
# {'G6_Up', 'G21_Up'}  implies  {'G47_Up', 'G94_Up'}
# {'G47_Up', 'G94_Up'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G58_Down', 'G32_Down'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G32_Down'}  implies  {'G21_Up', 'G38_Down'}
# {'G38_Down', 'G32_Down'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G32_Down'}  implies  {'G47_Up', 'G21_Up'}
# {'G70_Down', 'G32_Down'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G32_Down'}  implies  {'G21_Up', 'G94_Up'}
# {'G21_Up', 'G32_Down'}  implies  {'G6_Up', 'G94_Up'}
# {'G70_Down', 'G91_Up'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G21_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G6_Up', 'G21_Up'}
# {'G69_Down', 'G28_Down'}  implies  {'G6_Up', 'G52_Down'}
# {'G6_Up', 'G28_Down'}  implies  {'G58_Down', 'G47_Up'}
# {'G70_Down', 'G28_Down'}  implies  {'G6_Up', 'G47_Up'}
# {'G87_Up', 'G28_Down'}  implies  {'G88_Down', 'G6_Up'}
# {'G87_Up', 'G6_Up'}  implies  {'G68_Down', 'G28_Down'}
# {'G87_Up', 'G28_Down'}  implies  {'G41_Down', 'G6_Up'}
# {'G70_Down', 'G58_Down'}  implies  {'G6_Up', 'G65_Down'}
# {'G58_Down', 'G6_Up'}  implies  {'G65_Down', 'G91_Up'}
# {'G6_Up', 'G65_Down'}  implies  {'G58_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G58_Down', 'G65_Down'}
# {'G65_Down', 'G91_Up'}  implies  {'G58_Down', 'G6_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G94_Up', 'G65_Down'}
# {'G58_Down', 'G94_Up'}  implies  {'G6_Up', 'G65_Down'}
# {'G58_Down', 'G65_Down'}  implies  {'G6_Up', 'G94_Up'}
# {'G70_Down', 'G91_Up'}  implies  {'G58_Down', 'G6_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G70_Down', 'G91_Up'}
# {'G70_Down', 'G58_Down'}  implies  {'G6_Up', 'G94_Up'}
# {'G70_Down', 'G6_Up'}  implies  {'G58_Down', 'G94_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G6_Up', 'G94_Up'}  implies  {'G58_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G58_Down', 'G94_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G58_Down', 'G6_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G6_Up', 'G82_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G6_Up', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G6_Up', 'G96_Down'}
# {'G6_Up', 'G38_Down'}  implies  {'G52_Down', 'G91_Up'}
# {'G38_Down', 'G91_Up'}  implies  {'G6_Up', 'G52_Down'}
# {'G6_Up', 'G38_Down'}  implies  {'G94_Up', 'G52_Down'}
# {'G38_Down', 'G94_Up'}  implies  {'G6_Up', 'G52_Down'}
# {'G38_Down', 'G52_Down'}  implies  {'G6_Up', 'G94_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G58_Down', 'G6_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G70_Down', 'G58_Down'}
# {'G58_Down', 'G91_Up'}  implies  {'G6_Up', 'G38_Down'}
# {'G6_Up', 'G38_Down'}  implies  {'G58_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G58_Down', 'G38_Down'}
# {'G38_Down', 'G91_Up'}  implies  {'G58_Down', 'G6_Up'}
# {'G58_Down', 'G38_Down'}  implies  {'G6_Up', 'G47_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G58_Down', 'G6_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G6_Up', 'G47_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G70_Down', 'G6_Up'}
# {'G47_Up', 'G91_Up'}  implies  {'G6_Up', 'G38_Down'}
# {'G38_Down', 'G91_Up'}  implies  {'G6_Up', 'G47_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G65_Down', 'G91_Up'}
# {'G70_Down', 'G91_Up'}  implies  {'G6_Up', 'G38_Down'}
# {'G6_Up', 'G38_Down'}  implies  {'G70_Down', 'G91_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G94_Up', 'G91_Up'}
# {'G38_Down', 'G94_Up'}  implies  {'G6_Up', 'G91_Up'}
# {'G38_Down', 'G91_Up'}  implies  {'G6_Up', 'G94_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G6_Up', 'G38_Down'}
# {'G6_Up', 'G38_Down'}  implies  {'G94_Up', 'G67_Up'}
# {'G38_Down', 'G94_Up'}  implies  {'G6_Up', 'G67_Up'}
# {'G38_Down', 'G67_Up'}  implies  {'G6_Up', 'G94_Up'}
# {'G70_Down', 'G58_Down'}  implies  {'G6_Up', 'G47_Up'}
# {'G70_Down', 'G6_Up'}  implies  {'G58_Down', 'G47_Up'}
# {'G70_Down', 'G47_Up'}  implies  {'G58_Down', 'G6_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G70_Down', 'G47_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G47_Up', 'G91_Up'}
# {'G6_Up', 'G47_Up'}  implies  {'G58_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G58_Down', 'G47_Up'}
# {'G47_Up', 'G91_Up'}  implies  {'G58_Down', 'G6_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G47_Up', 'G94_Up'}
# {'G58_Down', 'G47_Up'}  implies  {'G6_Up', 'G94_Up'}
# {'G6_Up', 'G94_Up'}  implies  {'G58_Down', 'G47_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G47_Up', 'G65_Down'}
# {'G70_Down', 'G6_Up'}  implies  {'G47_Up', 'G91_Up'}
# {'G6_Up', 'G47_Up'}  implies  {'G70_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G70_Down', 'G47_Up'}
# {'G70_Down', 'G6_Up'}  implies  {'G47_Up', 'G94_Up'}
# {'G70_Down', 'G47_Up'}  implies  {'G6_Up', 'G94_Up'}
# {'G6_Up', 'G47_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G6_Up', 'G47_Up'}
# {'G70_Down', 'G6_Up'}  implies  {'G47_Up', 'G67_Up'}
# {'G70_Down', 'G47_Up'}  implies  {'G6_Up', 'G67_Up'}
# {'G70_Down', 'G91_Up'}  implies  {'G6_Up', 'G65_Down'}
# {'G70_Down', 'G6_Up'}  implies  {'G94_Up', 'G65_Down'}
# {'G6_Up', 'G91_Up'}  implies  {'G94_Up', 'G65_Down'}
# {'G65_Down', 'G91_Up'}  implies  {'G6_Up', 'G94_Up'}
# {'G70_Down', 'G67_Up'}  implies  {'G6_Up', 'G65_Down'}
# {'G58_Down', 'G6_Up'}  implies  {'G32_Down', 'G65_Down'}
# {'G58_Down', 'G32_Down'}  implies  {'G6_Up', 'G65_Down'}
# {'G70_Down', 'G58_Down'}  implies  {'G6_Up', 'G32_Down'}
# {'G70_Down', 'G6_Up'}  implies  {'G58_Down', 'G32_Down'}
# {'G70_Down', 'G32_Down'}  implies  {'G58_Down', 'G6_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G70_Down', 'G32_Down'}
# {'G58_Down', 'G32_Down'}  implies  {'G70_Down', 'G6_Up'}
# {'G6_Up', 'G32_Down'}  implies  {'G70_Down', 'G58_Down'}
# {'G58_Down', 'G6_Up'}  implies  {'G32_Down', 'G91_Up'}
# {'G6_Up', 'G32_Down'}  implies  {'G58_Down', 'G91_Up'}
# {'G58_Down', 'G32_Down'}  implies  {'G6_Up', 'G94_Up'}
# {'G70_Down', 'G32_Down'}  implies  {'G6_Up', 'G38_Down'}
# {'G6_Up', 'G38_Down'}  implies  {'G70_Down', 'G32_Down'}
# {'G6_Up', 'G38_Down'}  implies  {'G32_Down', 'G91_Up'}
# {'G6_Up', 'G38_Down'}  implies  {'G32_Down', 'G67_Up'}
# {'G38_Down', 'G32_Down'}  implies  {'G6_Up', 'G67_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G47_Up', 'G32_Down'}
# {'G70_Down', 'G6_Up'}  implies  {'G47_Up', 'G32_Down'}
# {'G6_Up', 'G91_Up'}  implies  {'G47_Up', 'G32_Down'}
# {'G70_Down', 'G6_Up'}  implies  {'G32_Down', 'G65_Down'}
# {'G70_Down', 'G32_Down'}  implies  {'G6_Up', 'G65_Down'}
# {'G6_Up', 'G65_Down'}  implies  {'G70_Down', 'G32_Down'}
# {'G6_Up', 'G91_Up'}  implies  {'G32_Down', 'G65_Down'}
# {'G32_Down', 'G91_Up'}  implies  {'G6_Up', 'G65_Down'}
# {'G6_Up', 'G65_Down'}  implies  {'G32_Down', 'G91_Up'}
# {'G70_Down', 'G6_Up'}  implies  {'G32_Down', 'G91_Up'}
# {'G70_Down', 'G32_Down'}  implies  {'G6_Up', 'G91_Up'}
# {'G70_Down', 'G91_Up'}  implies  {'G6_Up', 'G32_Down'}
# {'G6_Up', 'G32_Down'}  implies  {'G70_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G70_Down', 'G32_Down'}
# {'G32_Down', 'G91_Up'}  implies  {'G70_Down', 'G6_Up'}
# {'G70_Down', 'G32_Down'}  implies  {'G6_Up', 'G94_Up'}
# {'G70_Down', 'G6_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G6_Up', 'G94_Up'}  implies  {'G70_Down', 'G91_Up'}
# {'G6_Up', 'G91_Up'}  implies  {'G70_Down', 'G94_Up'}
# {'G58_Down', 'G10_Down'}  implies  {'G6_Up', 'G21_Up'}
# {'G6_Up', 'G10_Down'}  implies  {'G47_Up', 'G21_Up'}
# {'G47_Up', 'G28_Down'}  implies  {'G6_Up', 'G10_Down'}
# {'G10_Down', 'G28_Down'}  implies  {'G6_Up', 'G47_Up'}
# {'G70_Down', 'G58_Down'}  implies  {'G6_Up', 'G10_Down'}
# {'G70_Down', 'G6_Up'}  implies  {'G58_Down', 'G10_Down'}
# {'G70_Down', 'G10_Down'}  implies  {'G58_Down', 'G6_Up'}
# {'G58_Down', 'G6_Up'}  implies  {'G70_Down', 'G10_Down'}
# {'G58_Down', 'G10_Down'}  implies  {'G70_Down', 'G6_Up'}
# {'G6_Up', 'G10_Down'}  implies  {'G70_Down', 'G58_Down'}
# {'G58_Down', 'G91_Up'}  implies  {'G6_Up', 'G10_Down'}
# {'G6_Up', 'G10_Down'}  implies  {'G58_Down', 'G91_Up'}
# {'G38_Down', 'G10_Down'}  implies  {'G6_Up', 'G47_Up'}
# {'G47_Up', 'G10_Down'}  implies  {'G6_Up', 'G38_Down'}
# {'G70_Down', 'G38_Down'}  implies  {'G6_Up', 'G10_Down'}
# {'G38_Down', 'G91_Up'}  implies  {'G6_Up', 'G10_Down'}
# {'G38_Down', 'G94_Up'}  implies  {'G6_Up', 'G10_Down'}
# {'G58_Down', 'G10_Down'}  implies  {'G6_Up', 'G47_Up'}
# {'G6_Up', 'G47_Up'}  implies  {'G58_Down', 'G10_Down'}
# {'G6_Up', 'G10_Down'}  implies  {'G58_Down', 'G47_Up'}
# {'G47_Up', 'G10_Down'}  implies  {'G58_Down', 'G6_Up'}
# {'G70_Down', 'G10_Down'}  implies  {'G6_Up', 'G47_Up'}
# {'G6_Up', 'G47_Up'}  implies  {'G70_Down', 'G10_Down'}
# {'G6_Up', 'G10_Down'}  implies  {'G70_Down', 'G47_Up'}
# {'G47_Up', 'G10_Down'}  implies  {'G70_Down', 'G6_Up'}
# {'G47_Up', 'G91_Up'}  implies  {'G6_Up', 'G10_Down'}
# {'G10_Down', 'G91_Up'}  implies  {'G6_Up', 'G47_Up'}
# {'G10_Down', 'G91_Up'}  implies  {'G6_Up', 'G65_Down'}
# {'G10_Down', 'G67_Up'}  implies  {'G6_Up', 'G65_Down'}
# {'G58_Down', 'G32_Down'}  implies  {'G6_Up', 'G10_Down'}
# {'G10_Down', 'G32_Down'}  implies  {'G58_Down', 'G6_Up'}
# {'G6_Up', 'G10_Down'}  implies  {'G94_Up', 'G91_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G6_Up', 'G10_Down'}
# {'G6_Up', 'G10_Down'}  implies  {'G94_Up', 'G67_Up'}
# {'G10_Down', 'G94_Up'}  implies  {'G6_Up', 'G67_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G13_Down', 'G16_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G13_Down', 'G16_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G16_Down', 'G82_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G13_Down', 'G16_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G96_Down', 'G16_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G13_Down', 'G16_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G16_Down', 'G82_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G13_Down', 'G16_Down'}
# {'G96_Down', 'G82_Down'}  implies  {'G13_Down', 'G16_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G21_Up', 'G13_Down'}
# {'G44_Down', 'G72_Up'}  implies  {'G13_Down', 'G59_Up'}
# {'G72_Up', 'G13_Down'}  implies  {'G44_Down', 'G59_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G44_Down', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G72_Up', 'G44_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G44_Down', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G44_Down', 'G82_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G44_Down', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G44_Down', 'G96_Down'}
# {'G97_Down', 'G59_Up'}  implies  {'G44_Down', 'G13_Down'}
# {'G44_Down', 'G13_Down'}  implies  {'G97_Down', 'G59_Up'}
# {'G44_Down', 'G59_Up'}  implies  {'G97_Down', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G44_Down'}
# {'G44_Down', 'G72_Up'}  implies  {'G13_Down', 'G82_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G44_Down', 'G82_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G44_Down', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G72_Up', 'G44_Down'}
# {'G44_Down', 'G72_Up'}  implies  {'G96_Down', 'G13_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G44_Down', 'G13_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G44_Down', 'G96_Down'}
# {'G96_Down', 'G13_Down'}  implies  {'G72_Up', 'G44_Down'}
# {'G44_Down', 'G72_Up'}  implies  {'G97_Down', 'G13_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G44_Down', 'G97_Down'}
# {'G72_Up', 'G97_Down'}  implies  {'G44_Down', 'G13_Down'}
# {'G44_Down', 'G13_Down'}  implies  {'G72_Up', 'G97_Down'}
# {'G96_Down', 'G82_Down'}  implies  {'G44_Down', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G44_Down', 'G96_Down'}
# {'G44_Down', 'G97_Down'}  implies  {'G13_Down', 'G82_Down'}
# {'G97_Down', 'G13_Down'}  implies  {'G44_Down', 'G82_Down'}
# {'G97_Down', 'G82_Down'}  implies  {'G44_Down', 'G13_Down'}
# {'G44_Down', 'G13_Down'}  implies  {'G97_Down', 'G82_Down'}
# {'G44_Down', 'G82_Down'}  implies  {'G97_Down', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G44_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G13_Down', 'G57_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G72_Up', 'G57_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G13_Down', 'G59_Up'}
# {'G13_Down', 'G82_Down'}  implies  {'G72_Up', 'G59_Up'}
# {'G82_Down', 'G59_Up'}  implies  {'G72_Up', 'G13_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G59_Up', 'G82_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G13_Down', 'G82_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G72_Up', 'G82_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G13_Down', 'G59_Up'}
# {'G72_Up', 'G97_Down'}  implies  {'G13_Down', 'G59_Up'}
# {'G72_Up', 'G13_Down'}  implies  {'G97_Down', 'G59_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G97_Down', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G13_Down', 'G78_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G89_Up', 'G13_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G95_Down', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G95_Down', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G68_Down', 'G13_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G70_Down', 'G13_Down'}
# {'G96_Down', 'G82_Down'}  implies  {'G13_Down', 'G59_Up'}
# {'G96_Down', 'G13_Down'}  implies  {'G59_Up', 'G82_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G13_Down', 'G82_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G96_Down', 'G82_Down'}
# {'G97_Down', 'G82_Down'}  implies  {'G13_Down', 'G59_Up'}
# {'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G59_Up'}
# {'G82_Down', 'G59_Up'}  implies  {'G97_Down', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G82_Down'}
# {'G97_Down', 'G59_Up'}  implies  {'G96_Down', 'G13_Down'}
# {'G96_Down', 'G13_Down'}  implies  {'G97_Down', 'G59_Up'}
# {'G96_Down', 'G59_Up'}  implies  {'G97_Down', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G96_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G13_Down', 'G78_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G36_Up', 'G13_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G36_Up', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G36_Up', 'G82_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G36_Up', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G96_Down', 'G36_Up'}
# {'G72_Up', 'G96_Down'}  implies  {'G13_Down', 'G82_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G96_Down', 'G82_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G96_Down', 'G13_Down'}
# {'G96_Down', 'G13_Down'}  implies  {'G72_Up', 'G82_Down'}
# {'G96_Down', 'G82_Down'}  implies  {'G72_Up', 'G13_Down'}
# {'G72_Up', 'G97_Down'}  implies  {'G13_Down', 'G82_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G97_Down', 'G82_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G97_Down', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G72_Up'}
# {'G72_Up', 'G82_Down'}  implies  {'G95_Down', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G95_Down', 'G72_Up'}
# {'G72_Up', 'G96_Down'}  implies  {'G97_Down', 'G13_Down'}
# {'G72_Up', 'G13_Down'}  implies  {'G97_Down', 'G96_Down'}
# {'G72_Up', 'G97_Down'}  implies  {'G96_Down', 'G13_Down'}
# {'G96_Down', 'G13_Down'}  implies  {'G72_Up', 'G97_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G13_Down', 'G78_Up'}
# {'G72_Up', 'G82_Down'}  implies  {'G36_Up', 'G13_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G68_Down', 'G13_Down'}
# {'G97_Down', 'G96_Down'}  implies  {'G13_Down', 'G82_Down'}
# {'G96_Down', 'G13_Down'}  implies  {'G97_Down', 'G82_Down'}
# {'G96_Down', 'G82_Down'}  implies  {'G97_Down', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G96_Down'}
# {'G44_Down', 'G59_Up'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G44_Down', 'ALL'}
# {'G44_Down', 'G13_Down', 'G59_Up'}  implies  {'ALL'}
# {'G44_Down', 'G72_Up'}  implies  {'ALL', 'G13_Down'}
# {'G72_Up', 'G44_Down', 'G13_Down'}  implies  {'ALL'}
# {'G44_Down', 'G82_Down'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G44_Down', 'ALL'}
# {'G44_Down', 'G13_Down', 'G82_Down'}  implies  {'ALL'}
# {'G44_Down', 'G96_Down'}  implies  {'ALL', 'G13_Down'}
# {'ALL', 'G13_Down'}  implies  {'G44_Down', 'G96_Down'}
# {'G44_Down', 'G96_Down', 'G13_Down'}  implies  {'ALL'}
# {'G44_Down', 'G97_Down'}  implies  {'ALL', 'G13_Down'}
# {'G97_Down', 'G13_Down'}  implies  {'G44_Down', 'ALL'}
# {'G44_Down', 'G13_Down', 'G97_Down'}  implies  {'ALL'}
# {'G72_Up', 'G59_Up'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G72_Up', 'ALL'}
# {'G72_Up', 'G13_Down', 'G59_Up'}  implies  {'ALL'}
# {'G82_Down', 'G59_Up'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'ALL', 'G82_Down'}
# {'G82_Down', 'G13_Down', 'G59_Up'}  implies  {'ALL'}
# {'G96_Down', 'G59_Up'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G96_Down', 'ALL'}
# {'G96_Down', 'G13_Down', 'G59_Up'}  implies  {'ALL'}
# {'G97_Down', 'G59_Up'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'ALL'}
# {'G97_Down', 'G13_Down', 'G59_Up'}  implies  {'ALL'}
# {'G72_Up', 'G82_Down'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G72_Up', 'ALL'}
# {'G72_Up', 'G13_Down', 'G82_Down'}  implies  {'ALL'}
# {'G72_Up', 'G96_Down'}  implies  {'ALL', 'G13_Down'}
# {'G72_Up', 'G96_Down', 'G13_Down'}  implies  {'ALL'}
# {'G72_Up', 'G97_Down'}  implies  {'ALL', 'G13_Down'}
# {'G97_Down', 'G13_Down'}  implies  {'G72_Up', 'ALL'}
# {'G72_Up', 'G13_Down', 'G97_Down'}  implies  {'ALL'}
# {'G96_Down', 'G82_Down'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G96_Down', 'ALL'}
# {'G96_Down', 'G13_Down', 'G82_Down'}  implies  {'ALL'}
# {'G97_Down', 'G82_Down'}  implies  {'ALL', 'G13_Down'}
# {'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'ALL'}
# {'G97_Down', 'G13_Down', 'G82_Down'}  implies  {'ALL'}
# {'G97_Down', 'G96_Down'}  implies  {'ALL', 'G13_Down'}
# {'G97_Down', 'G96_Down', 'G13_Down'}  implies  {'ALL'}
# {'G72_Up', 'G96_Down'}  implies  {'G15_Down', 'G59_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G44_Down', 'G16_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G66_Up', 'G16_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G16_Down', 'G59_Up'}
# {'G72_Up', 'G96_Down'}  implies  {'G16_Down', 'G59_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G97_Down', 'G16_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G96_Down', 'G16_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G16_Down', 'G82_Down'}
# {'G72_Up', 'G97_Down'}  implies  {'G16_Down', 'G82_Down'}
# {'G72_Up', 'G82_Down'}  implies  {'G19_Down', 'G59_Up'}
# {'G58_Down', 'G38_Down'}  implies  {'G70_Down', 'G21_Up'}
# {'G58_Down', 'G91_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G21_Up', 'G38_Down'}  implies  {'G58_Down', 'G91_Up'}
# {'G21_Up', 'G91_Up'}  implies  {'G58_Down', 'G38_Down'}
# {'G38_Down', 'G91_Up'}  implies  {'G58_Down', 'G21_Up'}
# {'G58_Down', 'G47_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G70_Down', 'G21_Up'}  implies  {'G58_Down', 'G47_Up'}
# {'G58_Down', 'G47_Up'}  implies  {'G70_Down', 'G21_Up'}
# {'G58_Down', 'G47_Up'}  implies  {'G21_Up', 'G91_Up'}
# {'G47_Up', 'G21_Up'}  implies  {'G58_Down', 'G91_Up'}
# {'G47_Up', 'G91_Up'}  implies  {'G58_Down', 'G21_Up'}
# {'G21_Up', 'G91_Up'}  implies  {'G58_Down', 'G47_Up'}
# {'G58_Down', 'G47_Up'}  implies  {'G21_Up', 'G94_Up'}
# {'G58_Down', 'G21_Up'}  implies  {'G47_Up', 'G94_Up'}
# {'G58_Down', 'G94_Up'}  implies  {'G47_Up', 'G21_Up'}
# {'G47_Up', 'G21_Up'}  implies  {'G58_Down', 'G94_Up'}
# {'G47_Up', 'G94_Up'}  implies  {'G58_Down', 'G21_Up'}
# {'G21_Up', 'G94_Up'}  implies  {'G58_Down', 'G47_Up'}
# {'G58_Down', 'G91_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G58_Down', 'G94_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G58_Down', 'G21_Up'}  implies  {'G94_Up', 'G65_Down'}
# {'G58_Down', 'G32_Down'}  implies  {'G21_Up', 'G94_Up'}
# {'G21_Up', 'G32_Down'}  implies  {'G58_Down', 'G94_Up'}
# {'G58_Down', 'G91_Up'}  implies  {'G70_Down', 'G21_Up'}
# {'G58_Down', 'G21_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G21_Up', 'G94_Up'}  implies  {'G58_Down', 'G91_Up'}
# {'G21_Up', 'G91_Up'}  implies  {'G58_Down', 'G94_Up'}
# {'G58_Down', 'G91_Up'}  implies  {'G21_Up', 'G67_Up'}
# {'G21_Up', 'G91_Up'}  implies  {'G58_Down', 'G67_Up'}
# {'G72_Up', 'G82_Down'}  implies  {'G21_Up', 'G59_Up'}
# {'G72_Up', 'G82_Down'}  implies  {'G97_Down', 'G21_Up'}
# {'G47_Up', 'G38_Down'}  implies  {'G70_Down', 'G21_Up'}
# {'G47_Up', 'G91_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G38_Down', 'G91_Up'}  implies  {'G47_Up', 'G21_Up'}
# {'G47_Up', 'G94_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G21_Up', 'G38_Down'}  implies  {'G47_Up', 'G94_Up'}
# {'G38_Down', 'G91_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G70_Down', 'G32_Down'}  implies  {'G21_Up', 'G38_Down'}
# {'G38_Down', 'G32_Down'}  implies  {'G70_Down', 'G21_Up'}
# {'G94_Up', 'G32_Down'}  implies  {'G21_Up', 'G38_Down'}
# {'G38_Down', 'G32_Down'}  implies  {'G21_Up', 'G94_Up'}
# {'G70_Down', 'G91_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G21_Up', 'G38_Down'}  implies  {'G70_Down', 'G91_Up'}
# {'G70_Down', 'G94_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G21_Up', 'G38_Down'}  implies  {'G70_Down', 'G94_Up'}
# {'G21_Up', 'G38_Down'}  implies  {'G94_Up', 'G91_Up'}
# {'G38_Down', 'G94_Up'}  implies  {'G21_Up', 'G91_Up'}
# {'G38_Down', 'G91_Up'}  implies  {'G21_Up', 'G94_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G47_Up', 'G91_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G47_Up', 'G21_Up'}  implies  {'G94_Up', 'G65_Down'}
# {'G21_Up', 'G94_Up'}  implies  {'G47_Up', 'G32_Down'}
# {'G94_Up', 'G32_Down'}  implies  {'G47_Up', 'G21_Up'}
# {'G47_Up', 'G21_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G47_Up', 'G94_Up'}  implies  {'G21_Up', 'G91_Up'}
# {'G47_Up', 'G91_Up'}  implies  {'G21_Up', 'G94_Up'}
# {'G21_Up', 'G94_Up'}  implies  {'G47_Up', 'G91_Up'}
# {'G21_Up', 'G91_Up'}  implies  {'G47_Up', 'G94_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G47_Up', 'G21_Up'}
# {'G70_Down', 'G91_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G65_Down', 'G91_Up'}  implies  {'G70_Down', 'G21_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G21_Up', 'G65_Down'}  implies  {'G94_Up', 'G91_Up'}
# {'G21_Up', 'G91_Up'}  implies  {'G94_Up', 'G65_Down'}
# {'G65_Down', 'G91_Up'}  implies  {'G21_Up', 'G94_Up'}
# {'G91_Up', 'G67_Up'}  implies  {'G21_Up', 'G65_Down'}
# {'G70_Down', 'G21_Up'}  implies  {'G94_Up', 'G91_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G70_Down', 'G21_Up'}
# {'G70_Down', 'G91_Up'}  implies  {'G21_Up', 'G67_Up'}
# {'G58_Down', 'G47_Up'}  implies  {'G21_Up', 'G10_Down'}
# {'G21_Up', 'G10_Down'}  implies  {'G58_Down', 'G47_Up'}
# {'G70_Down', 'G10_Down'}  implies  {'G58_Down', 'G21_Up'}
# {'G21_Up', 'G10_Down'}  implies  {'G70_Down', 'G58_Down'}
# {'G58_Down', 'G91_Up'}  implies  {'G21_Up', 'G10_Down'}
# {'G21_Up', 'G10_Down'}  implies  {'G58_Down', 'G91_Up'}
# {'G58_Down', 'G94_Up'}  implies  {'G21_Up', 'G10_Down'}
# {'G21_Up', 'G10_Down'}  implies  {'G58_Down', 'G94_Up'}
# {'G38_Down', 'G10_Down'}  implies  {'G47_Up', 'G21_Up'}
# {'G38_Down', 'G10_Down'}  implies  {'G70_Down', 'G21_Up'}
# {'G38_Down', 'G94_Up'}  implies  {'G21_Up', 'G10_Down'}
# {'G10_Down', 'G94_Up'}  implies  {'G21_Up', 'G38_Down'}
# {'G70_Down', 'G10_Down'}  implies  {'G47_Up', 'G21_Up'}
# {'G47_Up', 'G21_Up'}  implies  {'G10_Down', 'G91_Up'}
# {'G47_Up', 'G10_Down'}  implies  {'G21_Up', 'G91_Up'}
# {'G47_Up', 'G91_Up'}  implies  {'G21_Up', 'G10_Down'}
# {'G21_Up', 'G10_Down'}  implies  {'G47_Up', 'G91_Up'}
# {'G47_Up', 'G94_Up'}  implies  {'G21_Up', 'G10_Down'}
# {'G21_Up', 'G10_Down'}  implies  {'G47_Up', 'G94_Up'}
# {'G21_Up', 'G10_Down'}  implies  {'G65_Down', 'G91_Up'}
# {'G21_Up', 'G10_Down'}  implies  {'G94_Up', 'G91_Up'}
# {'G10_Down', 'G94_Up'}  implies  {'G21_Up', 'G91_Up'}
# {'G10_Down', 'G91_Up'}  implies  {'G21_Up', 'G94_Up'}
# {'G94_Up', 'G91_Up'}  implies  {'G21_Up', 'G10_Down'}
# {'G88_Down', 'G52_Down'}  implies  {'G24_Down', 'G28_Down'}
# {'G88_Down', 'G69_Down'}  implies  {'G24_Down', 'G28_Down'}
# {'G54_Up', 'G88_Down'}  implies  {'G24_Down', 'G28_Down'}
# {'G88_Down', 'G41_Down'}  implies  {'G24_Down', 'G28_Down'}
# {'G72_Up', 'G59_Up'}  implies  {'G24_Down', 'G82_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G24_Down', 'G59_Up'}
# {'G54_Up', 'G88_Down'}  implies  {'G24_Down', 'G69_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G54_Up', 'G69_Down'}
# {'G72_Up', 'G96_Down'}  implies  {'G24_Down', 'G82_Down'}
# {'G88_Down', 'G2_Down'}  implies  {'G41_Down', 'G24_Down'}
# {'G88_Down', 'G41_Down'}  implies  {'G2_Down', 'G24_Down'}
# {'G88_Down', 'G41_Down'}  implies  {'G47_Up', 'G24_Down'}
# {'G54_Up', 'G24_Down'}  implies  {'G87_Up', 'G81_Up'}
# {'G54_Up', 'G88_Down'}  implies  {'G81_Up', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G54_Up', 'G81_Up'}
# {'G54_Up', 'G81_Up'}  implies  {'G8_Up', 'G24_Down'}
# {'G54_Up', 'G8_Up'}  implies  {'G81_Up', 'G24_Down'}
# {'G54_Up', 'G24_Down'}  implies  {'G81_Up', 'G8_Up'}
# {'G81_Up', 'G8_Up'}  implies  {'G54_Up', 'G24_Down'}
# {'G81_Up', 'G24_Down'}  implies  {'G54_Up', 'G8_Up'}
# {'G8_Up', 'G24_Down'}  implies  {'G54_Up', 'G81_Up'}
# {'G54_Up', 'G24_Down'}  implies  {'G80_Down', 'G81_Up'}
# {'G54_Up', 'G88_Down'}  implies  {'G87_Up', 'G24_Down'}
# {'G54_Up', 'G24_Down'}  implies  {'G87_Up', 'G8_Up'}
# {'G54_Up', 'G8_Up'}  implies  {'G88_Down', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G54_Up', 'G8_Up'}
# {'G54_Up', 'G88_Down'}  implies  {'G80_Down', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G54_Up', 'G80_Down'}
# {'G54_Up', 'G80_Down'}  implies  {'G8_Up', 'G24_Down'}
# {'G54_Up', 'G8_Up'}  implies  {'G80_Down', 'G24_Down'}
# {'G54_Up', 'G88_Down'}  implies  {'G41_Down', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G54_Up', 'G41_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G87_Up', 'G81_Up'}
# {'G88_Down', 'G81_Up'}  implies  {'G8_Up', 'G24_Down'}
# {'G88_Down', 'G8_Up'}  implies  {'G81_Up', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G81_Up', 'G8_Up'}
# {'G81_Up', 'G8_Up'}  implies  {'G88_Down', 'G24_Down'}
# {'G88_Down', 'G81_Up'}  implies  {'G41_Down', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G81_Up', 'G41_Down'}
# {'G88_Down', 'G80_Down'}  implies  {'G81_Up', 'G24_Down'}
# {'G88_Down', 'G41_Down'}  implies  {'G8_Up', 'G24_Down'}
# {'G88_Down', 'G8_Up'}  implies  {'G41_Down', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G41_Down', 'G8_Up'}
# {'G88_Down', 'G80_Down'}  implies  {'G8_Up', 'G24_Down'}
# {'G88_Down', 'G8_Up'}  implies  {'G80_Down', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G80_Down', 'G8_Up'}
# {'G54_Up', 'Breast Cancer'}  implies  {'G81_Up', 'G24_Down'}
# {'G54_Up', 'G81_Up'}  implies  {'Breast Cancer', 'G24_Down'}
# {'G54_Up', 'G24_Down'}  implies  {'G81_Up', 'Breast Cancer'}
# {'G81_Up', 'G24_Down'}  implies  {'G54_Up', 'Breast Cancer'}
# {'G54_Up', 'G88_Down'}  implies  {'Breast Cancer', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G54_Up', 'Breast Cancer'}
# {'G54_Up', 'G24_Down', 'G88_Down'}  implies  {'Breast Cancer'}
# {'G54_Up', 'G24_Down'}  implies  {'Breast Cancer', 'G8_Up'}
# {'G8_Up', 'G24_Down'}  implies  {'G54_Up', 'Breast Cancer'}
# {'G54_Up', 'G8_Up', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G54_Up', 'G80_Down'}  implies  {'Breast Cancer', 'G24_Down'}
# {'G54_Up', 'G80_Down', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G88_Down', 'G81_Up'}  implies  {'Breast Cancer', 'G24_Down'}
# {'G88_Down', 'G24_Down'}  implies  {'G81_Up', 'Breast Cancer'}
# {'G88_Down', 'G81_Up', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G81_Up', 'G24_Down'}  implies  {'Breast Cancer', 'G8_Up'}
# {'Breast Cancer', 'G8_Up'}  implies  {'G81_Up', 'G24_Down'}
# {'G81_Up', 'G8_Up', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G80_Down', 'G81_Up'}  implies  {'Breast Cancer', 'G24_Down'}
# {'G80_Down', 'Breast Cancer'}  implies  {'G81_Up', 'G24_Down'}
# {'G80_Down', 'G24_Down'}  implies  {'G81_Up', 'Breast Cancer'}
# {'Breast Cancer', 'G24_Down'}  implies  {'G80_Down', 'G81_Up'}
# {'G80_Down', 'G81_Up', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G88_Down', 'G24_Down'}  implies  {'Breast Cancer', 'G8_Up'}
# {'G8_Up', 'G24_Down'}  implies  {'G88_Down', 'Breast Cancer'}
# {'G88_Down', 'G8_Up', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G88_Down', 'G80_Down'}  implies  {'Breast Cancer', 'G24_Down'}
# {'G88_Down', 'G80_Down', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G80_Down', 'G24_Down'}  implies  {'Breast Cancer', 'G8_Up'}
# {'G8_Up', 'G24_Down'}  implies  {'G80_Down', 'Breast Cancer'}
# {'G80_Down', 'G8_Up', 'G24_Down'}  implies  {'Breast Cancer'}
# {'G69_Down', 'G28_Down'}  implies  {'G87_Up', 'G52_Down'}
# {'G87_Up', 'G52_Down'}  implies  {'G28_Down', 'G69_Down'}
# {'G87_Up', 'G28_Down'}  implies  {'G52_Down', 'G69_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G87_Up', 'G69_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G67_Up', 'G69_Down'}
# {'G69_Down', 'G28_Down'}  implies  {'G2_Down', 'G52_Down'}
# {'G2_Down', 'G52_Down'}  implies  {'G28_Down', 'G69_Down'}
# {'G2_Down', 'G28_Down'}  implies  {'G52_Down', 'G69_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G2_Down', 'G69_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G2_Down', 'G38_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G2_Down', 'G52_Down'}
# {'G2_Down', 'G28_Down'}  implies  {'G47_Up', 'G52_Down'}
# {'G2_Down', 'G52_Down'}  implies  {'G65_Down', 'G28_Down'}
# {'G2_Down', 'G28_Down'}  implies  {'G87_Up', 'G52_Down'}
# {'G87_Up', 'G28_Down'}  implies  {'G2_Down', 'G52_Down'}
# {'G2_Down', 'G52_Down'}  implies  {'G41_Down', 'G28_Down'}
# {'G41_Down', 'G52_Down'}  implies  {'G2_Down', 'G28_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G2_Down', 'G41_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G2_Down', 'G52_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G58_Down', 'G38_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G58_Down', 'G52_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G38_Down', 'G69_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G52_Down', 'G69_Down'}
# {'G38_Down', 'G52_Down'}  implies  {'G65_Down', 'G28_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G87_Up', 'G38_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G87_Up', 'G52_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G91_Up', 'G52_Down'}
# {'G38_Down', 'G52_Down'}  implies  {'G94_Up', 'G28_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G41_Down', 'G38_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G41_Down', 'G52_Down'}
# {'G38_Down', 'G52_Down'}  implies  {'G28_Down', 'G67_Up'}
# {'G52_Down', 'G28_Down'}  implies  {'G47_Up', 'G69_Down'}
# {'G88_Down', 'G28_Down'}  implies  {'G87_Up', 'G52_Down'}
# {'G87_Up', 'G28_Down'}  implies  {'G67_Up', 'G52_Down'}
# {'G38_Down', 'G52_Down'}  implies  {'G32_Down', 'G28_Down'}
# {'G87_Up', 'G28_Down'}  implies  {'G32_Down', 'G52_Down'}
# {'G41_Down', 'G52_Down'}  implies  {'G28_Down', 'G69_Down'}
# {'G69_Down', 'G28_Down'}  implies  {'G41_Down', 'G52_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G47_Up', 'G52_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G41_Down', 'G65_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G87_Up', 'G41_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G87_Up', 'G52_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G88_Down', 'G52_Down'}
# {'G88_Down', 'G28_Down'}  implies  {'G41_Down', 'G52_Down'}
# {'G52_Down', 'G28_Down'}  implies  {'G41_Down', 'G67_Up'}
# {'G38_Down', 'G28_Down'}  implies  {'G2_Down', 'G58_Down'}
# {'G2_Down', 'G28_Down'}  implies  {'G58_Down', 'G47_Up'}
# {'G58_Down', 'G38_Down'}  implies  {'G65_Down', 'G28_Down'}
# {'G70_Down', 'G28_Down'}  implies  {'G58_Down', 'G47_Up'}
# {'G69_Down', 'G28_Down'}  implies  {'G2_Down', 'G41_Down'}
# {'G2_Down', 'G41_Down'}  implies  {'G28_Down', 'G69_Down'}
# {'G2_Down', 'G28_Down'}  implies  {'G41_Down', 'G69_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G2_Down', 'G69_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G38_Down', 'G69_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G41_Down', 'G69_Down'}
# {'G88_Down', 'G28_Down'}  implies  {'G47_Up', 'G69_Down'}
# {'G69_Down', 'G28_Down'}  implies  {'G41_Down', 'G32_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G47_Up', 'G69_Down'}
# {'G69_Down', 'G28_Down'}  implies  {'G87_Up', 'G41_Down'}
# {'G87_Up', 'G41_Down'}  implies  {'G28_Down', 'G69_Down'}
# {'G87_Up', 'G28_Down'}  implies  {'G41_Down', 'G69_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G87_Up', 'G69_Down'}
# {'G2_Down', 'G38_Down'}  implies  {'G65_Down', 'G28_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G2_Down', 'G32_Down'}
# {'G2_Down', 'G28_Down'}  implies  {'G41_Down', 'G38_Down'}
# {'G41_Down', 'G38_Down'}  implies  {'G2_Down', 'G28_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G2_Down', 'G38_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G2_Down', 'G41_Down'}
# {'G2_Down', 'G28_Down'}  implies  {'G41_Down', 'G47_Up'}
# {'G2_Down', 'G41_Down'}  implies  {'G65_Down', 'G28_Down'}
# {'G2_Down', 'G28_Down'}  implies  {'G87_Up', 'G41_Down'}
# {'G87_Up', 'G28_Down'}  implies  {'G2_Down', 'G41_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G47_Up', 'G67_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G65_Down', 'G28_Down'}
# {'G41_Down', 'G38_Down'}  implies  {'G65_Down', 'G28_Down'}
# {'G38_Down', 'G28_Down'}  implies  {'G32_Down', 'G67_Up'}
# {'G70_Down', 'G38_Down'}  implies  {'G28_Down', 'G67_Up'}
# {'G38_Down', 'G28_Down'}  implies  {'G41_Down', 'G91_Up'}
# {'G38_Down', 'G28_Down'}  implies  {'G41_Down', 'G67_Up'}
# {'G47_Up', 'G28_Down'}  implies  {'G70_Down', 'G88_Down'}
# {'G88_Down', 'G28_Down'}  implies  {'G41_Down', 'G47_Up'}
# {'G88_Down', 'G87_Up'}  implies  {'G81_Up', 'G28_Down'}
# {'G87_Up', 'G28_Down'}  implies  {'G70_Down', 'G88_Down'}
# {'G88_Down', 'G87_Up'}  implies  {'G41_Down', 'G28_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G10_Down', 'G52_Down'}
# {'G10_Down', 'G28_Down'}  implies  {'G41_Down', 'G52_Down'}
# {'G10_Down', 'G28_Down'}  implies  {'G67_Up', 'G52_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G10_Down', 'G69_Down'}
# {'G10_Down', 'G28_Down'}  implies  {'G2_Down', 'G94_Up'}
# {'G38_Down', 'G10_Down'}  implies  {'G65_Down', 'G28_Down'}
# {'G38_Down', 'G10_Down'}  implies  {'G94_Up', 'G28_Down'}
# {'G88_Down', 'G28_Down'}  implies  {'G87_Up', 'G10_Down'}
# {'G41_Down', 'G28_Down'}  implies  {'G87_Up', 'G10_Down'}
# {'G10_Down', 'G28_Down'}  implies  {'G87_Up', 'G41_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G33_Up', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G33_Up', 'G82_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G33_Up', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G33_Up', 'G96_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G34_Down', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G34_Down', 'G82_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G34_Down', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G34_Down', 'G96_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G44_Down', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G44_Down', 'G82_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G44_Down', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G44_Down', 'G96_Down'}
# {'G97_Down', 'G59_Up'}  implies  {'G44_Down', 'G72_Up'}
# {'G44_Down', 'G72_Up'}  implies  {'G97_Down', 'G59_Up'}
# {'G44_Down', 'G59_Up'}  implies  {'G97_Down', 'G72_Up'}
# {'G72_Up', 'G59_Up'}  implies  {'G97_Down', 'G44_Down'}
# {'G82_Down', 'G59_Up'}  implies  {'G44_Down', 'G96_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G44_Down', 'G82_Down'}
# {'G97_Down', 'G82_Down'}  implies  {'G44_Down', 'G59_Up'}
# {'G44_Down', 'G82_Down'}  implies  {'G97_Down', 'G59_Up'}
# {'G82_Down', 'G59_Up'}  implies  {'G97_Down', 'G44_Down'}
# {'G44_Down', 'G59_Up'}  implies  {'G97_Down', 'G82_Down'}
# {'G97_Down', 'G59_Up'}  implies  {'G44_Down', 'G96_Down'}
# {'G44_Down', 'G96_Down'}  implies  {'G97_Down', 'G59_Up'}
# {'G44_Down', 'G59_Up'}  implies  {'G97_Down', 'G96_Down'}
# {'G96_Down', 'G59_Up'}  implies  {'G97_Down', 'G44_Down'}
# {'G96_Down', 'G82_Down'}  implies  {'G44_Down', 'G72_Up'}
# {'G72_Up', 'G82_Down'}  implies  {'G44_Down', 'G96_Down'}
# {'G97_Down', 'G82_Down'}  implies  {'G44_Down', 'G72_Up'}
# {'G44_Down', 'G72_Up'}  implies  {'G97_Down', 'G82_Down'}
# {'G44_Down', 'G82_Down'}  implies  {'G97_Down', 'G72_Up'}
# {'G72_Up', 'G82_Down'}  implies  {'G97_Down', 'G44_Down'}
# {'G97_Down', 'G96_Down'}  implies  {'G44_Down', 'G72_Up'}
# {'G72_Up', 'G97_Down'}  implies  {'G44_Down', 'G96_Down'}
# {'G97_Down', 'G82_Down'}  implies  {'G44_Down', 'G96_Down'}
# {'G96_Down', 'G82_Down'}  implies  {'G97_Down', 'G44_Down'}
# {'G44_Down', 'G59_Up'}  implies  {'G72_Up', 'ALL'}
# {'G72_Up', 'G59_Up'}  implies  {'G44_Down', 'ALL'}
# {'G44_Down', 'G72_Up', 'G59_Up'}  implies  {'ALL'}
# ...
# {'G97_Down', 'G96_Down', 'G13_Down'}  implies  {'G59_Up', 'G82_Down', 'G72_Up', 'ALL', 'G44_Down'}
# {'G44_Down', 'G13_Down', 'G97_Down'}  implies  {'G59_Up', 'G82_Down', 'G72_Up', 'G96_Down', 'ALL'}
# {'G97_Down', 'G96_Down', 'G82_Down'}  implies  {'G59_Up', 'G13_Down', 'G72_Up', 'ALL', 'G44_Down'}
# {'G97_Down', 'G72_Up', 'G82_Down'}  implies  {'G59_Up', 'G13_Down', 'G96_Down', 'ALL', 'G44_Down'}
# {'G72_Up', 'G96_Down', 'G97_Down'}  implies  {'G59_Up', 'G13_Down', 'G82_Down', 'ALL', 'G44_Down'}
# {'G97_Down', 'ALL', 'G59_Up'}  implies  {'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}
# {'G97_Down', 'ALL', 'G13_Down'}  implies  {'G59_Up', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}
# {'G97_Down', 'ALL', 'G82_Down'}  implies  {'G59_Up', 'G13_Down', 'G72_Up', 'G96_Down', 'G44_Down'}
# {'G72_Up', 'ALL', 'G97_Down'}  implies  {'G59_Up', 'G13_Down', 'G82_Down', 'G96_Down', 'G44_Down'}
# {'G97_Down', 'G96_Down', 'ALL'}  implies  {'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'G44_Down'}
# {'G44_Down', 'ALL', 'G97_Down'}  implies  {'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down'}
# {'G97_Down', 'G44_Down', 'G59_Up'}  implies  {'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'ALL'}
# {'G97_Down', 'G44_Down', 'G82_Down'}  implies  {'G59_Up', 'G13_Down', 'G72_Up', 'G96_Down', 'ALL'}
# {'G44_Down', 'G72_Up', 'G97_Down'}  implies  {'G59_Up', 'G13_Down', 'G82_Down', 'G96_Down', 'ALL'}
# {'G44_Down', 'G96_Down', 'G97_Down'}  implies  {'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'ALL'}
# {'G82_Down', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G72_Up', 'G96_Down', 'ALL', 'G44_Down'}
# {'G72_Up', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G82_Down', 'G96_Down', 'ALL', 'G44_Down'}
# {'G96_Down', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G82_Down', 'G72_Up', 'ALL', 'G44_Down'}
# {'G44_Down', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'ALL'}
# {'G82_Down', 'G72_Up', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G96_Down', 'ALL', 'G44_Down'}
# {'G82_Down', 'G96_Down', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G72_Up', 'ALL', 'G44_Down'}
# {'G72_Up', 'G96_Down', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G82_Down', 'ALL', 'G44_Down'}
# {'ALL', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}
# {'G82_Down', 'ALL', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G72_Up', 'G96_Down', 'G44_Down'}
# {'G72_Up', 'ALL', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G82_Down', 'G96_Down', 'G44_Down'}
# {'G96_Down', 'ALL', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G82_Down', 'G72_Up', 'G44_Down'}
# {'G44_Down', 'ALL', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down'}
# {'G82_Down', 'G44_Down', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G72_Up', 'G96_Down', 'ALL'}
# {'G44_Down', 'G72_Up', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G82_Down', 'G96_Down', 'ALL'}
# {'G44_Down', 'G96_Down', 'G59_Up'}  implies  {'G97_Down', 'G13_Down', 'G82_Down', 'G72_Up', 'ALL'}
# {'G72_Up', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G96_Down', 'ALL', 'G44_Down'}
# {'G96_Down', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G72_Up', 'ALL', 'G44_Down'}
# {'G44_Down', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G72_Up', 'G96_Down', 'ALL'}
# {'G72_Up', 'G96_Down', 'G13_Down'}  implies  {'G97_Down', 'G59_Up', 'G82_Down', 'ALL', 'G44_Down'}
# {'G72_Up', 'G44_Down', 'G13_Down'}  implies  {'G97_Down', 'G59_Up', 'G82_Down', 'G96_Down', 'ALL'}
# {'G44_Down', 'G96_Down', 'G13_Down'}  implies  {'G97_Down', 'G59_Up', 'G82_Down', 'G72_Up', 'ALL'}
# {'ALL', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G72_Up', 'G96_Down', 'G44_Down'}
# {'G72_Up', 'ALL', 'G13_Down'}  implies  {'G97_Down', 'G59_Up', 'G82_Down', 'G96_Down', 'G44_Down'}
# {'G96_Down', 'ALL', 'G13_Down'}  implies  {'G97_Down', 'G59_Up', 'G82_Down', 'G72_Up', 'G44_Down'}
# {'G44_Down', 'ALL', 'G13_Down'}  implies  {'G97_Down', 'G59_Up', 'G82_Down', 'G72_Up', 'G96_Down'}
# {'G72_Up', 'G96_Down', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'ALL', 'G44_Down'}
# {'G72_Up', 'ALL', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G96_Down', 'G44_Down'}
# {'G96_Down', 'ALL', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G72_Up', 'G44_Down'}
# {'G44_Down', 'ALL', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G72_Up', 'G96_Down'}
# {'G44_Down', 'G72_Up', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G96_Down', 'ALL'}
# {'G44_Down', 'G96_Down', 'G82_Down'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G72_Up', 'ALL'}
# {'G72_Up', 'G96_Down', 'ALL'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G44_Down'}
# {'G44_Down', 'ALL', 'G72_Up'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G96_Down'}
# {'G44_Down', 'G96_Down', 'G72_Up'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'ALL'}
# {'G44_Down', 'G96_Down', 'ALL'}  implies  {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up'}
# {'G82_Down', 'G97_Down', 'G96_Down', 'G59_Up'}  implies  {'G72_Up', 'G44_Down', 'ALL', 'G13_Down'}
# {'G97_Down', 'G82_Down', 'G72_Up', 'G59_Up'}  implies  {'G44_Down', 'G96_Down', 'ALL', 'G13_Down'}
# {'G97_Down', 'G72_Up', 'G96_Down', 'G59_Up'}  implies  {'G44_Down', 'ALL', 'G13_Down', 'G82_Down'}
# {'G82_Down', 'G97_Down', 'G13_Down', 'G59_Up'}  implies  {'G72_Up', 'G96_Down', 'ALL', 'G44_Down'}
# {'G97_Down', 'G72_Up', 'G13_Down', 'G59_Up'}  implies  {'G44_Down', 'G96_Down', 'ALL', 'G82_Down'}
# {'G97_Down', 'G96_Down', 'G13_Down', 'G59_Up'}  implies  {'G72_Up', 'ALL', 'G44_Down', 'G82_Down'}
# {'G97_Down', 'G96_Down', 'G13_Down', 'G82_Down'}  implies  {'G72_Up', 'ALL', 'G44_Down', 'G59_Up'}
# {'G97_Down', 'G72_Up', 'G13_Down', 'G82_Down'}  implies  {'G44_Down', 'G96_Down', 'ALL', 'G59_Up'}
# {'G72_Up', 'G96_Down', 'G13_Down', 'G97_Down'}  implies  {'G82_Down', 'G44_Down', 'ALL', 'G59_Up'}
# {'G97_Down', 'G44_Down', 'G13_Down', 'G59_Up'}  implies  {'G72_Up', 'G96_Down', 'ALL', 'G82_Down'}
# {'G97_Down', 'G44_Down', 'G13_Down', 'G82_Down'}  implies  {'G72_Up', 'G96_Down', 'ALL', 'G59_Up'}
# {'G72_Up', 'G44_Down', 'G13_Down', 'G97_Down'}  implies  {'G82_Down', 'G96_Down', 'ALL', 'G59_Up'}
# {'G44_Down', 'G96_Down', 'G13_Down', 'G97_Down'}  implies  {'G82_Down', 'G72_Up', 'ALL', 'G59_Up'}
# {'G97_Down', 'G72_Up', 'G96_Down', 'G82_Down'}  implies  {'G44_Down', 'ALL', 'G13_Down', 'G59_Up'}
# {'G82_Down', 'G97_Down', 'ALL', 'G59_Up'}  implies  {'G72_Up', 'G96_Down', 'G44_Down', 'G13_Down'}
# {'G97_Down', 'G72_Up', 'ALL', 'G59_Up'}  implies  {'G44_Down', 'G96_Down', 'G13_Down', 'G82_Down'}
# {'G97_Down', 'G96_Down', 'ALL', 'G59_Up'}  implies  {'G72_Up', 'G44_Down', 'G13_Down', 'G82_Down'}
# {'G97_Down', 'ALL', 'G13_Down', 'G59_Up'}  implies  {'G72_Up', 'G96_Down', 'G44_Down', 'G82_Down'}
# {'G97_Down', 'ALL', 'G13_Down', 'G82_Down'}  implies  {'G72_Up', 'G96_Down', 'G44_Down', 'G59_Up'}
# {'G72_Up', 'ALL', 'G13_Down', 'G97_Down'}  implies  {'G82_Down', 'G44_Down', 'G96_Down', 'G59_Up'}
# {'G97_Down', 'G96_Down', 'ALL', 'G13_Down'}  implies  {'G82_Down', 'G72_Up', 'G44_Down', 'G59_Up'}
# {'G97_Down', 'G72_Up', 'ALL', 'G82_Down'}  implies  {'G44_Down', 'G96_Down', 'G13_Down', 'G59_Up'}
# {'G72_Up', 'G96_Down', 'ALL', 'G97_Down'}  implies  {'G82_Down', 'G44_Down', 'G13_Down', 'G59_Up'}
# {'G97_Down', 'G44_Down', 'ALL', 'G59_Up'}  implies  {'G72_Up', 'G96_Down', 'G13_Down', 'G82_Down'}
# {'G97_Down', 'G44_Down', 'ALL', 'G82_Down'}  implies  {'G72_Up', 'G96_Down', 'G13_Down', 'G59_Up'}
# {'G44_Down', 'ALL', 'G72_Up', 'G97_Down'}  implies  {'G82_Down', 'G96_Down', 'G13_Down', 'G59_Up'}
# {'G97_Down', 'G44_Down', 'G72_Up', 'G59_Up'}  implies  {'G96_Down', 'ALL', 'G13_Down', 'G82_Down'}
# {'G97_Down', 'G44_Down', 'G96_Down', 'G59_Up'}  implies  {'G72_Up', 'ALL', 'G13_Down', 'G82_Down'}
# {'G97_Down', 'G44_Down', 'G96_Down', 'G82_Down'}  implies  {'G72_Up', 'ALL', 'G13_Down', 'G59_Up'}
# {'G97_Down', 'G44_Down', 'G72_Up', 'G82_Down'}  implies  {'G96_Down', 'ALL', 'G13_Down', 'G59_Up'}
# {'G44_Down', 'G96_Down', 'G72_Up', 'G97_Down'}  implies  {'G82_Down', 'ALL', 'G13_Down', 'G59_Up'}
# {'G82_Down', 'G72_Up', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'ALL', 'G44_Down'}
# {'G82_Down', 'G96_Down', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G44_Down', 'ALL', 'G72_Up'}
# {'G72_Up', 'G96_Down', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'ALL', 'G44_Down', 'G82_Down'}
# {'G82_Down', 'G44_Down', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'ALL', 'G72_Up'}
# {'G72_Up', 'G44_Down', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'ALL', 'G82_Down'}
# {'G44_Down', 'G96_Down', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'ALL', 'G72_Up', 'G82_Down'}
# {'G82_Down', 'G72_Up', 'G96_Down', 'G59_Up'}  implies  {'G97_Down', 'G44_Down', 'ALL', 'G13_Down'}
# {'G82_Down', 'ALL', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'G44_Down', 'G72_Up'}
# {'G72_Up', 'ALL', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'G44_Down', 'G82_Down'}
# {'G96_Down', 'ALL', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G44_Down', 'G72_Up', 'G82_Down'}
# {'G44_Down', 'ALL', 'G13_Down', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'G72_Up', 'G82_Down'}
# {'G82_Down', 'G72_Up', 'ALL', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'G44_Down', 'G13_Down'}
# {'G82_Down', 'G96_Down', 'ALL', 'G59_Up'}  implies  {'G72_Up', 'G97_Down', 'G44_Down', 'G13_Down'}
# {'G72_Up', 'G96_Down', 'ALL', 'G59_Up'}  implies  {'G97_Down', 'G44_Down', 'G13_Down', 'G82_Down'}
# {'G82_Down', 'G44_Down', 'ALL', 'G59_Up'}  implies  {'G72_Up', 'G97_Down', 'G96_Down', 'G13_Down'}
# {'G44_Down', 'ALL', 'G72_Up', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'G13_Down', 'G82_Down'}
# {'G44_Down', 'G96_Down', 'ALL', 'G59_Up'}  implies  {'G72_Up', 'G97_Down', 'G13_Down', 'G82_Down'}
# {'G82_Down', 'G44_Down', 'G72_Up', 'G59_Up'}  implies  {'G97_Down', 'G96_Down', 'ALL', 'G13_Down'}
# {'G82_Down', 'G44_Down', 'G96_Down', 'G59_Up'}  implies  {'G72_Up', 'G97_Down', 'ALL', 'G13_Down'}
# {'G44_Down', 'G96_Down', 'G72_Up', 'G59_Up'}  implies  {'G97_Down', 'ALL', 'G13_Down', 'G82_Down'}
# {'G72_Up', 'G96_Down', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'ALL', 'G44_Down', 'G59_Up'}
# {'G72_Up', 'G44_Down', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G96_Down', 'ALL', 'G59_Up'}
# {'G44_Down', 'G96_Down', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'ALL', 'G72_Up', 'G59_Up'}
# {'G72_Up', 'G44_Down', 'G96_Down', 'G13_Down'}  implies  {'G82_Down', 'G97_Down', 'ALL', 'G59_Up'}
# {'G72_Up', 'ALL', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G96_Down', 'G44_Down', 'G59_Up'}
# {'G96_Down', 'ALL', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G44_Down', 'G72_Up', 'G59_Up'}
# {'G44_Down', 'ALL', 'G13_Down', 'G82_Down'}  implies  {'G97_Down', 'G96_Down', 'G72_Up', 'G59_Up'}
# {'G72_Up', 'G96_Down', 'ALL', 'G13_Down'}  implies  {'G82_Down', 'G97_Down', 'G44_Down', 'G59_Up'}
# {'G72_Up', 'G44_Down', 'ALL', 'G13_Down'}  implies  {'G82_Down', 'G97_Down', 'G96_Down', 'G59_Up'}
# {'G44_Down', 'ALL', 'G72_Up', 'G82_Down'}  implies  {'G97_Down', 'G96_Down', 'G13_Down', 'G59_Up'}
# {'G44_Down', 'G96_Down', 'ALL', 'G82_Down'}  implies  {'G72_Up', 'G97_Down', 'G13_Down', 'G59_Up'}
# {'G44_Down', 'G96_Down', 'G72_Up', 'G82_Down'}  implies  {'G97_Down', 'ALL', 'G13_Down', 'G59_Up'}
# {'G44_Down', 'G96_Down', 'ALL', 'G72_Up'}  implies  {'G82_Down', 'G97_Down', 'G13_Down', 'G59_Up'}
# {'G97_Down', 'G59_Up', 'G82_Down', 'G72_Up', 'G96_Down'}  implies  {'G44_Down', 'ALL', 'G13_Down'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G96_Down'}  implies  {'G72_Up', 'ALL', 'G44_Down'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up'}  implies  {'G44_Down', 'G96_Down', 'ALL'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G72_Up', 'G96_Down'}  implies  {'G44_Down', 'ALL', 'G82_Down'}
# {'G97_Down', 'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down'}  implies  {'G44_Down', 'ALL', 'G59_Up'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G44_Down'}  implies  {'G72_Up', 'G96_Down', 'ALL'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G72_Up', 'G44_Down'}  implies  {'G96_Down', 'ALL', 'G82_Down'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G96_Down', 'G44_Down'}  implies  {'G72_Up', 'ALL', 'G82_Down'}
# {'G97_Down', 'G13_Down', 'G82_Down', 'G96_Down', 'G44_Down'}  implies  {'G72_Up', 'ALL', 'G59_Up'}
# {'G97_Down', 'G13_Down', 'G82_Down', 'G72_Up', 'G44_Down'}  implies  {'G96_Down', 'ALL', 'G59_Up'}
# {'G97_Down', 'G13_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'G82_Down', 'ALL', 'G59_Up'}
# {'G97_Down', 'G59_Up', 'G82_Down', 'G96_Down', 'ALL'}  implies  {'G72_Up', 'G44_Down', 'G13_Down'}
# {'G97_Down', 'G59_Up', 'G82_Down', 'G72_Up', 'ALL'}  implies  {'G44_Down', 'G96_Down', 'G13_Down'}
# {'G97_Down', 'G59_Up', 'G72_Up', 'G96_Down', 'ALL'}  implies  {'G44_Down', 'G13_Down', 'G82_Down'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'ALL'}  implies  {'G72_Up', 'G96_Down', 'G44_Down'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G72_Up', 'ALL'}  implies  {'G44_Down', 'G96_Down', 'G82_Down'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G96_Down', 'ALL'}  implies  {'G72_Up', 'G44_Down', 'G82_Down'}
# {'G97_Down', 'G13_Down', 'G72_Up', 'G96_Down', 'ALL'}  implies  {'G82_Down', 'G44_Down', 'G59_Up'}
# {'G97_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'ALL'}  implies  {'G44_Down', 'G13_Down', 'G59_Up'}
# {'G97_Down', 'G59_Up', 'G82_Down', 'G96_Down', 'G44_Down'}  implies  {'G72_Up', 'ALL', 'G13_Down'}
# {'G97_Down', 'G59_Up', 'G82_Down', 'G72_Up', 'G44_Down'}  implies  {'G96_Down', 'ALL', 'G13_Down'}
# {'G97_Down', 'G59_Up', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'ALL', 'G13_Down', 'G82_Down'}
# {'G97_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'ALL', 'G13_Down', 'G59_Up'}
# {'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down'}  implies  {'G97_Down', 'ALL', 'G44_Down'}
# {'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'G44_Down'}  implies  {'G97_Down', 'G96_Down', 'ALL'}
# {'G59_Up', 'G13_Down', 'G82_Down', 'G96_Down', 'G44_Down'}  implies  {'G97_Down', 'ALL', 'G72_Up'}
# {'G59_Up', 'G13_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'G97_Down', 'ALL', 'G82_Down'}
# {'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'ALL'}  implies  {'G97_Down', 'G96_Down', 'G44_Down'}
# {'G59_Up', 'G13_Down', 'G82_Down', 'G96_Down', 'ALL'}  implies  {'G97_Down', 'G44_Down', 'G72_Up'}
# {'G59_Up', 'G13_Down', 'G72_Up', 'G96_Down', 'ALL'}  implies  {'G97_Down', 'G44_Down', 'G82_Down'}
# {'G59_Up', 'G82_Down', 'G72_Up', 'G96_Down', 'ALL'}  implies  {'G97_Down', 'G44_Down', 'G13_Down'}
# {'G59_Up', 'G82_Down', 'G72_Up', 'ALL', 'G44_Down'}  implies  {'G97_Down', 'G96_Down', 'G13_Down'}
# {'G59_Up', 'G82_Down', 'G96_Down', 'ALL', 'G44_Down'}  implies  {'G72_Up', 'G97_Down', 'G13_Down'}
# {'G59_Up', 'G72_Up', 'G96_Down', 'ALL', 'G44_Down'}  implies  {'G97_Down', 'G13_Down', 'G82_Down'}
# {'G59_Up', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'G97_Down', 'ALL', 'G13_Down'}
# {'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'G97_Down', 'ALL', 'G59_Up'}
# {'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'ALL'}  implies  {'G97_Down', 'G44_Down', 'G59_Up'}
# {'G13_Down', 'G82_Down', 'G72_Up', 'ALL', 'G44_Down'}  implies  {'G97_Down', 'G96_Down', 'G59_Up'}
# {'G82_Down', 'G72_Up', 'G96_Down', 'ALL', 'G44_Down'}  implies  {'G97_Down', 'G13_Down', 'G59_Up'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down'}  implies  {'G44_Down', 'ALL'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G96_Down', 'G44_Down'}  implies  {'G72_Up', 'ALL'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'G44_Down'}  implies  {'G96_Down', 'ALL'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'ALL', 'G82_Down'}
# {'G97_Down', 'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'ALL', 'G59_Up'}
# {'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'G97_Down', 'ALL'}
# {'G97_Down', 'G59_Up', 'G13_Down', 'G82_Down', 'G72_Up', 'G96_Down', 'G44_Down'}  implies  {'ALL'}
# number of length-8 frequent itemsets: 1
# number of all lengths frequent itemsets:12879
